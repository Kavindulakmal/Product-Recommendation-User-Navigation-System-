# %% [markdown]
# Content-based filtering is a type of recommender system that attempts to guess what a user may like based on that user's activity. Content-based filtering makes recommendations by using keywords and attributes assigned to objects in a database (e.g., items in an online marketplace) and matching them to a user profile.

# %%
import pandas as pd

# %% [markdown]
# # Loading Dataset

# %%
df = pd.read_csv('dataset.csv')

# %%
df.head()
# Out:
#    id                                        description
# 0   1  Active classic boxers - There's a reason why o...
# 1   2  Active sport boxer briefs - Skinning up Glory ...
# 2   3  Active sport briefs - These superbreathable no...
# 3   4  Alpine guide pants - Skin in, climb ice, switc...
# 4   5  Alpine wind jkt - On high ridges, steep ice an...

# %% [markdown]
# # EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
# id             500 non-null int64
# description    500 non-null object
# dtypes: int64(1), object(1)
# memory usage: 7.9+ KB

# %%
df.shape
# Out:
# (500, 2)

# %% [markdown]
# Dataset has two columns and 500 data rows

# %%
df.describe()
# Out:
#                id
# count  500.000000
# mean   250.500000
# std    144.481833
# min      1.000000
# 25%    125.750000
# 50%    250.500000
# 75%    375.250000
# max    500.000000

# %%
df['description'][0]
# Out:
# 'Active classic boxers - There\'s a reason why our boxers are a cult favorite - they keep their cool, especially in sticky situations. The quick-drying, lightweight underwear takes up minimal space in a travel pack. An exposed, brushed waistband offers next-to-skin softness, five-panel construction with a traditional boxer back for a classic fit, and a functional fly. Made of 3.7-oz 100% recycled polyester with moisture-wicking performance. Inseam (size M) is 4 1/2". Recyclable through the Common Threads Recycling Program.<br><br><b>Details:</b><ul> <li>"Silky Capilene 1 fabric is ultralight, breathable and quick-to-dry"</li> <li>"Exposed, brushed elastic waistband for comfort"</li> <li>5-panel construction with traditional boxer back</li> <li>"Inseam (size M) is 4 1/2"""</li></ul><br><br><b>Fabric: </b>3.7-oz 100% all-recycled polyester with Gladiodor natural odor control for the garment. Recyclable through the Common Threads Recycling Program<br><br><b>Weight: </b>99 g (3.5 oz)<br><br>Made in Mexico.'

# %% [markdown]
# Contains html elements that needed to be cleaned

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ### Remove HTML Elements

# %%
import re


def remove_html_elements(text):
    return re.sub(r"<[a-z/]+>", " ", text) 

# example execution
print(remove_html_elements(df['description'][0]))
# Out:
# Active classic boxers - There's a reason why our boxers are a cult favorite - they keep their cool, especially in sticky situations. The quick-drying, lightweight underwear takes up minimal space in a travel pack. An exposed, brushed waistband offers next-to-skin softness, five-panel construction with a traditional boxer back for a classic fit, and a functional fly. Made of 3.7-oz 100% recycled polyester with moisture-wicking performance. Inseam (size M) is 4 1/2". Recyclable through the Common Threads Recycling Program.   Details:    "Silky Capilene 1 fabric is ultralight, breathable and quick-to-dry"   "Exposed, brushed elastic waistband for comfort"   5-panel construction with traditional boxer back   "Inseam (size M) is 4 1/2"""     Fabric:  3.7-oz 100% all-recycled polyester with Gladiodor natural odor control for the garment. Recyclable through the Common Threads Recycling Program   Weight:  99 g (3.5 oz)  Made in Mexico.

# %%
df['description'] = df['description'].apply(lambda x: remove_html_elements(x))

# %% [markdown]
# ### Remove special characters

# %%
def remove_special_char(text):
    return re.sub(r"[^A-Za-z]+", " ", text)

# example execution
print(remove_special_char(df['description'][0]))
# Out:
# Active classic boxers There s a reason why our boxers are a cult favorite they keep their cool especially in sticky situations The quick drying lightweight underwear takes up minimal space in a travel pack An exposed brushed waistband offers next to skin softness five panel construction with a traditional boxer back for a classic fit and a functional fly Made of oz recycled polyester with moisture wicking performance Inseam size M is Recyclable through the Common Threads Recycling Program Details Silky Capilene fabric is ultralight breathable and quick to dry Exposed brushed elastic waistband for comfort panel construction with traditional boxer back Inseam size M is Fabric oz all recycled polyester with Gladiodor natural odor control for the garment Recyclable through the Common Threads Recycling Program Weight g oz Made in Mexico

# %%
df['description'] = df['description'].apply(lambda x: remove_special_char(x))

# %% [markdown]
# ### Remove multiple spaces

# %%
def remove_whitespaces(text):
    return re.sub(' +', ' ', text)
    
# example execution to see the effect
print(remove_whitespaces(df['description'][0]))
# Out:
# Active classic boxers There s a reason why our boxers are a cult favorite they keep their cool especially in sticky situations The quick drying lightweight underwear takes up minimal space in a travel pack An exposed brushed waistband offers next to skin softness five panel construction with a traditional boxer back for a classic fit and a functional fly Made of oz recycled polyester with moisture wicking performance Inseam size M is Recyclable through the Common Threads Recycling Program Details Silky Capilene fabric is ultralight breathable and quick to dry Exposed brushed elastic waistband for comfort panel construction with traditional boxer back Inseam size M is Fabric oz all recycled polyester with Gladiodor natural odor control for the garment Recyclable through the Common Threads Recycling Program Weight g oz Made in Mexico

# %%
df['description'] = df['description'].apply(lambda x: remove_whitespaces(x))

# %% [markdown]
# ### Make all lowercase

# %%
df['description'] = df['description'].apply(lambda x: x.lower())
# example execution to see the effect
print(df['description'][0])
# Out:
# active classic boxers there s a reason why our boxers are a cult favorite they keep their cool especially in sticky situations the quick drying lightweight underwear takes up minimal space in a travel pack an exposed brushed waistband offers next to skin softness five panel construction with a traditional boxer back for a classic fit and a functional fly made of oz recycled polyester with moisture wicking performance inseam size m is recyclable through the common threads recycling program details silky capilene fabric is ultralight breathable and quick to dry exposed brushed elastic waistband for comfort panel construction with traditional boxer back inseam size m is fabric oz all recycled polyester with gladiodor natural odor control for the garment recyclable through the common threads recycling program weight g oz made in mexico

# %% [markdown]
# # Content Based Filtering

# %% [markdown]
# TfidfVectorizer is the base building block of many NLP pipelines. It is a simple technique to vectorize text documents — i.e. transform sentences into arrays of numbers — and use them in subsequent tasks.
#
# Linear Kernel is used when the data is Linearly separable, that is, it can be separated using a single Line. It is one of the most common kernels to be used. It is mostly used when there are a Large number of Features in a particular Data Set.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %%
t_vec = TfidfVectorizer(
    analyzer='word',
    ngram_range=(1, 3),
    min_df=0,
    stop_words='english')

# %%
tvec_matrix = t_vec.fit_transform(df['description'])

# %%
tvec_matrix
# Out:
# <500x49476 sparse matrix of type '<class 'numpy.float64'>'
# 	with 124956 stored elements in Compressed Sparse Row format>

# %% [markdown]
# **cosine similarity**
#
# Cosine similarity measures the similarity between two vectors of an inner product space.

# %%
cosine_similarities = linear_kernel(tvec_matrix, tvec_matrix)

# %%
results = {}

for idx, row in df.iterrows():
    print('{} {}'.format(idx, row))
    similar_indices = cosine_similarities[idx].argsort()[:-100:-1]
    similar_items = [(cosine_similarities[idx][i], df['id'][i]) for i in similar_indices]

    # remove first item, because it's a copy
    results[row['id']] = similar_items[1:]
# Out:
# 0 id                                                             1
# description    active classic boxers there s a reason why our...
# Name: 0, dtype: object
# 1 id                                                             2
# description    active sport boxer briefs skinning up glory re...
# Name: 1, dtype: object
# 2 id                                                             3
# description    active sport briefs these superbreathable no f...
# Name: 2, dtype: object
# 3 id                                                             4
# description    alpine guide pants skin in climb ice switch to...
# Name: 3, dtype: object
# 4 id                                                             5
# description    alpine wind jkt on high ridges steep ice and a...
# Name: 4, dtype: object
# 5 id                                                             6
# description    ascensionist jkt our most technical soft shell...
# Name: 5, dtype: object
# 6 id                                                             7
# description    atom a multitasker s cloud nine the atom plays...
# Name: 6, dtype: object
# 7 id                                                             8
# description    print banded betina btm our fullest coverage b...
# Name: 7, dtype: object
# 8 id                                                             9
# description    baby micro d luxe cardigan micro d luxe is a h...
# Name: 8, dtype: object
# 9 id                                                            10
# description    baby sun bucket hat this hat goes on when the ...
# Name: 9, dtype: object
# 10 id                                                            11
# description    baby sunshade top soft stretchy polyester fabr...
# Name: 10, dtype: object
# 11 id                                                            12
# description    baggies shorts even baggies our most popular s...
# Name: 11, dtype: object
# 12 id                                                            13
# description    beach bucket whenever you re at the junction o...
# Name: 12, dtype: object
# 13 id                                                            14
# description    better sweater jkt june nights camped out in n...
# Name: 13, dtype: object
# 14 id                                                            15
# description    borderless shorts in go forward where others c...
# Name: 14, dtype: object
# 15 id                                                            16
# description    borderless shorts in one of summertime s gifts...
# Name: 15, dtype: object
# 16 id                                                            17
# description    bucket hat besides its shade casting prowess t...
# Name: 16, dtype: object
# 17 id                                                            18
# description    cap bottoms spring skiing is as transient as t...
# Name: 17, dtype: object
# 18 id                                                            19
# description    cap boxer briefs on bivy or belay the form fit...
# Name: 18, dtype: object
# 19 id                                                            20
# description    cap graphic t shirt this tee is made from our ...
# Name: 19, dtype: object
# 20 id                                                            21
# description    cap t shirt minimally styled but technically e...
# Name: 20, dtype: object
# 21 id                                                            22
# description    cap t shirt this one revels in the sweat jambo...
# Name: 21, dtype: object
# 22 id                                                            23
# description    cap zip neck designed for wet then chill pursu...
# Name: 22, dtype: object
# 23 id                                                            24
# description    cap zip neck capilene provides excellent insul...
# Name: 23, dtype: object
# 24 id                                                            25
# description    cap bottoms for sufferfests like the grand in ...
# Name: 24, dtype: object
# 25 id                                                            26
# description    city by the sea t shirt illustrating the renai...
# Name: 25, dtype: object
# 26 id                                                            27
# description    compound cargo pants long the ultimate do ever...
# Name: 26, dtype: object
# 27 id                                                            28
# description    compound cargo pants reg the ultimate do every...
# Name: 27, dtype: object
# 28 id                                                            29
# description    continental shorts wrinkle resistant travel sh...
# Name: 28, dtype: object
# 29 id                                                            30
# description    cotton board shorts a classic in fabric and fo...
# Name: 29, dtype: object
# 30 id                                                            31
# description    crosstown crosstown or cross country this full...
# Name: 30, dtype: object
# 31 id                                                            32
# description    custodian pants long the graveyard shift has i...
# Name: 31, dtype: object
# 32 id                                                            33
# description    deep wading jkt whether you re chasing olympic...
# Name: 32, dtype: object
# 33 id                                                            34
# description    delivery shorts locals know all the best spots...
# Name: 33, dtype: object
# 34 id                                                            35
# description    down sweater vest impossible to confuse with t...
# Name: 34, dtype: object
# 35 id                                                            36
# description    dragoons t shirt these dragoons have dropped t...
# Name: 35, dtype: object
# 36 id                                                            37
# description    duck pants long essential wear for splitting l...
# Name: 36, dtype: object
# 37 id                                                            38
# description    elias fz sweatshirt clean as a wingate splitte...
# Name: 37, dtype: object
# 38 id                                                            39
# description    elias sweatshirt the dirtbagger s complete war...
# Name: 38, dtype: object
# 39 id                                                            40
# description    fezzman shirt look fresh even when you feel di...
# Name: 39, dtype: object
# 40 id                                                            41
# description    fish frenzy t shirt dependent on free flowing ...
# Name: 40, dtype: object
# 41 id                                                            42
# description    freewheeler this sturdy wheeled bag holds a we...
# Name: 41, dtype: object
# 42 id                                                            43
# description    gi ii pants the travel tested quick drying dur...
# Name: 42, dtype: object
# 43 id                                                            44
# description    gi ii shorts base camp favorites the gi ii s f...
# Name: 43, dtype: object
# 44 id                                                            45
# description    girl s boardie capris built for two week campi...
# Name: 44, dtype: object
# 45 id                                                            46
# description    girl s boardie shorts so you re raising neptun...
# Name: 45, dtype: object
# 46 id                                                            47
# description    girl s cotton tank dress this soft cotton dres...
# Name: 46, dtype: object
# 47 id                                                            48
# description    going big in b c poster one mans trash is anot...
# Name: 47, dtype: object
# 48 id                                                            49
# description    great divider from standing waves to blue wate...
# Name: 48, dtype: object
# 49 id                                                            50
# description    guidewater duffle max for serious angling expe...
# Name: 49, dtype: object
# 50 id                                                            51
# description    guidewater jkt pounding into the teeth of a no...
# Name: 50, dtype: object
# 51 id                                                            52
# description    guidewater shorts everything we love about the...
# Name: 51, dtype: object
# 52 id                                                            53
# description    guidewater vest find the tippet tool or fly bo...
# Name: 52, dtype: object
# 53 id                                                            54
# description    highwater pfd vest the constant boat angling d...
# Name: 53, dtype: object
# 54 id                                                            55
# description    hip chest pack ready to go vest free this is t...
# Name: 54, dtype: object
# 55 id                                                            56
# description    iceberg t shirt the effects of global warming ...
# Name: 55, dtype: object
# 56 id                                                            57
# description    insulator pants steelhead salmon trout they ar...
# Name: 56, dtype: object
# 57 id                                                            58
# description     logo t shirt soft wearing ringspun organic co...
# Name: 57, dtype: object
# 58 id                                                            59
# description    borderless gi shorts these shorts have a mud s...
# Name: 58, dtype: object
# 59 id                                                            60
# description    cap graphic tee kids live at full throttle all...
# Name: 59, dtype: object
# 60 id                                                            61
# description    cap bottoms like birds and clouds kids stay on...
# Name: 60, dtype: object
# 61 id                                                            62
# description    el cap jkt resistant to hard play but irresist...
# Name: 61, dtype: object
# 62 id                                                            63
# description    flying fish t shirt soft wearing ringspun orga...
# Name: 62, dtype: object
# 63 id                                                            64
# description    gpiw classic t shirt soft wearing ringspun org...
# Name: 63, dtype: object
# 64 id                                                            65
# description    live simply guitar t shirt soft wearing ringsp...
# Name: 64, dtype: object
# 65 id                                                            66
# description    synch marsupial the roomy kangaroo style front...
# Name: 65, dtype: object
# 66 id                                                            67
# description    torrentshell jkt when the barometric pressure ...
# Name: 66, dtype: object
# 67 id                                                            68
# description    la surfer maria t shirt pray for surf wearing ...
# Name: 67, dtype: object
# 68 id                                                            69
# description    lead an examined life poster guanacos standing...
# Name: 68, dtype: object
# 69 id                                                            70
# description    light and variable surf trunks our lightest le...
# Name: 69, dtype: object
# 70 id                                                            71
# description    live simply bug t shirt in nature live organis...
# Name: 70, dtype: object
# 71 id                                                            72
# description    live simply deer t shirt adaptability is simpl...
# Name: 71, dtype: object
# 72 id                                                            73
# description    live simply guitar t shirt live life unplugged...
# Name: 72, dtype: object
# 73 id                                                            74
# description    logo hat your unflappable road tripping compan...
# Name: 73, dtype: object
# 74 id                                                            75
# description    l s hooded rashguard the upf fabric of our lon...
# Name: 74, dtype: object
# 75 id                                                            76
# description    l s island hopper shirt serene in the face of ...
# Name: 75, dtype: object
# 76 id                                                            77
# description    l s rashguard the upf fabric of our long sleev...
# Name: 76, dtype: object
# 77 id                                                            78
# description    l s steersman shirt this ain t no city shirt u...
# Name: 77, dtype: object
# 78 id                                                            79
# description    lw endurance ankle socks fast forward pursuits...
# Name: 78, dtype: object
# 79 id                                                            80
# description    lw endurance quarter socks scraped taped or in...
# Name: 79, dtype: object
# 80 id                                                            81
# description    lw hiking crew socks like suites for your feet...
# Name: 80, dtype: object
# 81 id                                                            82
# description    lw r jkt high off the deck on warbonnet peak i...
# Name: 81, dtype: object
# 82 id                                                            83
# description    lw travel duffel this wanderer s bag is large ...
# Name: 82, dtype: object
# 83 id                                                            84
# description    lw travel pack in the lifelong search for a pl...
# Name: 83, dtype: object
# 84 id                                                            85
# description    m jkt made for those who thrive on thin and te...
# Name: 84, dtype: object
# 85 id                                                            86
# description    m pants volatile climates don t rule out big a...
# Name: 85, dtype: object
# 86 id                                                            87
# description    merino crew in a day packed with decisions thi...
# Name: 86, dtype: object
# 87 id                                                            88
# description    merino t shirt the bus ride out of tlachichuca...
# Name: 87, dtype: object
# 88 id                                                            89
# description    merino polo the feel is bohemian the look shou...
# Name: 88, dtype: object
# 89 id                                                            90
# description    merino t shirt stay calm and collected amid th...
# Name: 89, dtype: object
# 90 id                                                            91
# description    migration hemp shirt summerweight and soft the...
# Name: 90, dtype: object
# 91 id                                                            92
# description    minimalist board shorts in the minimalist is p...
# Name: 91, dtype: object
# 92 id                                                            93
# description    minimass the mini mass s lesser size lets you ...
# Name: 92, dtype: object
# 93 id                                                            94
# description    mlc wheelie the alpinist s saying speed is of ...
# Name: 93, dtype: object
# 94 id                                                            95
# description    mountain island t shirt for those who aspire t...
# Name: 94, dtype: object
# 95 id                                                            96
# description    nine trails jkt somewhere between the bridger ...
# Name: 95, dtype: object
# 96 id                                                            97
# description    nine trails shorts for those who view trails a...
# Name: 96, dtype: object
# 97 id                                                            98
# description    organic logo t shirt originally printed our fi...
# Name: 97, dtype: object
# 98 id                                                            99
# description    o web belt a social gadabout able to cross the...
# Name: 98, dtype: object
# 99 id                                                           100
# description    paddler board shorts built for maximum comfort...
# Name: 99, dtype: object
# 100 id                                                           101
# description    pataloha shirt early hawaiian shirts were pitc...
# Name: 100, dtype: object
# 101 id                                                           102
# description    planer t shirt the planer t shirt gives a nod ...
# Name: 101, dtype: object
# 102 id                                                           103
# description    platform t shirt imagine the problems of oil d...
# Name: 102, dtype: object
# 103 id                                                           104
# description    pocket pack for the savvy commuter our pocket ...
# Name: 103, dtype: object
# 104 id                                                           105
# description    r hoody spotted round the globe from high alpi...
# Name: 104, dtype: object
# 105 id                                                           106
# description    r p o desert sandstone corn snow iced up corne...
# Name: 105, dtype: object
# 106 id                                                           107
# description    rain shadow pants light enough to be an aftert...
# Name: 106, dtype: object
# 107 id                                                           108
# description    reg fit organic ctn jeans long organic cotton ...
# Name: 107, dtype: object
# 108 id                                                           109
# description    reg fit organic ctn jeans reg organic cotton d...
# Name: 108, dtype: object
# 109 id                                                           110
# description    relax fit organic ctn jeans shor the everyday ...
# Name: 109, dtype: object
# 110 id                                                           111
# description    remat one man s trash is another man or woman ...
# Name: 110, dtype: object
# 111 id                                                           112
# description    retro grade pants we used sonnie trotter s wis...
# Name: 111, dtype: object
# 112 id                                                           113
# description    riverwalker felt high water slick bedrock cobb...
# Name: 112, dtype: object
# 113 id                                                           114
# description    riverwalker studded high water slick bedrock c...
# Name: 113, dtype: object
# 114 id                                                           115
# description    rock guide shorts made for high open expanses ...
# Name: 114, dtype: object
# 115 id                                                           116
# description    rockpile t shirt beauty and bouldering are sta...
# Name: 115, dtype: object
# 116 id                                                           117
# description    runshade top from the trailhead at dawn throug...
# Name: 116, dtype: object
# 117 id                                                           118
# description    shop pants reg more at home under the truck th...
# Name: 117, dtype: object
# 118 id                                                           119
# description    shop pants short more at home under the truck ...
# Name: 118, dtype: object
# 119 id                                                           120
# description    simple guide jkt skin in by headlamp summit by...
# Name: 119, dtype: object
# 120 id                                                           121
# description    soaring jkt made for aerial pursuits the soari...
# Name: 120, dtype: object
# 121 id                                                           122
# description    sonar so no t shirt ear splitting sonar threat...
# Name: 121, dtype: object
# 122 id                                                           123
# description    special edition pataloha shirt this year s spe...
# Name: 122, dtype: object
# 123 id                                                           124
# description    squid t shirt artist tim tompkinson s original...
# Name: 123, dtype: object
# 124 id                                                           125
# description    s s island hopper shirt serene in the face of ...
# Name: 124, dtype: object
# 125 id                                                           126
# description    s s pragmatist shirt like a spare roll of duct...
# Name: 125, dtype: object
# 126 id                                                           127
# description    s s puckerware shirt in humidity that makes ot...
# Name: 126, dtype: object
# 127 id                                                           128
# description    s s stretch t ready for the full body workout ...
# Name: 127, dtype: object
# 128 id                                                           129
# description    sst jkt bristol bay tierra del fuego the russi...
# Name: 128, dtype: object
# 129 id                                                           130
# description    stormfront duffel designed to haul the goods p...
# Name: 129, dtype: object
# 130 id                                                           131
# description    stormfront pack wade a little too deep take on...
# Name: 130, dtype: object
# 131 id                                                           132
# description    stretch polo core to the nomadic lifestyle our...
# Name: 131, dtype: object
# 132 id                                                           133
# description    stretch wading belt this is the belt that come...
# Name: 132, dtype: object
# 133 id                                                           134
# description    sub divider just as tough and water resistant ...
# Name: 133, dtype: object
# 134 id                                                           135
# description    surf brim whether you re paddling back out or ...
# Name: 134, dtype: object
# 135 id                                                           136
# description    surf sneaker the footwear of choice for chasin...
# Name: 135, dtype: object
# 136 id                                                           137
# description    tech web belt this one s for the big jobs hois...
# Name: 136, dtype: object
# 137 id                                                           138
# description    text logo t shirt the text logo t shirt tells ...
# Name: 137, dtype: object
# 138 id                                                           139
# description    the more you know t shirt inspired by thoreau ...
# Name: 138, dtype: object
# 139 id                                                           140
# description    three trees shirt a summertime staple for airy...
# Name: 139, dtype: object
# 140 id                                                           141
# description    torrentshell pants they re lightweight waterpr...
# Name: 140, dtype: object
# 141 id                                                           142
# description    travel belt the traveler s ace keeps your pant...
# Name: 141, dtype: object
# 142 id                                                           143
# description    traverse jkt training routine number bicycle t...
# Name: 142, dtype: object
# 143 id                                                           144
# description    trout silhouette t shirt the simplicity of the...
# Name: 143, dtype: object
# 144 id                                                           145
# description    trucker hat for big rigs or big hair this is a...
# Name: 144, dtype: object
# 145 id                                                           146
# description    twenty three s board shorts stay covered in ou...
# Name: 145, dtype: object
# 146 id                                                           147
# description    ultra shorts our ever popular long cut quick d...
# Name: 146, dtype: object
# 147 id                                                           148
# description    ulw hiking crew socks the heat along the bouch...
# Name: 147, dtype: object
# 148 id                                                           149
# description    velocity cap when you re running the parched o...
# Name: 148, dtype: object
# 149 id                                                           150
# description    watermaster hip highs originally made for midw...
# Name: 149, dtype: object
# 150 id                                                           151
# description    world according to bikers t shir our health an...
# Name: 150, dtype: object
# 151 id                                                           152
# description    world trout t shirt james prosek recreates the...
# Name: 151, dtype: object
# 152 id                                                           153
# description    watermaster waders long blackberries barbwire ...
# Name: 152, dtype: object
# 153 id                                                           154
# description    watermaster waders short blackberries barbwire...
# Name: 153, dtype: object
# 154 id                                                           155
# description    active hipster while the perfect life might be...
# Name: 154, dtype: object
# 155 id                                                           156
# description    active mesh bra despite its inability to act a...
# Name: 155, dtype: object
# 156 id                                                           157
# description    all out capris jam a pair of these highly comp...
# Name: 156, dtype: object
# 157 id                                                           158
# description    all weather training top whether you re hittin...
# Name: 157, dtype: object
# 158 id                                                           159
# description    alpine guide pants skin in climb ice switch to...
# Name: 158, dtype: object
# 159 id                                                           160
# description    aravis hoody the lochsa river season ushers in...
# Name: 159, dtype: object
# 160 id                                                           161
# description    aravis jkt the highly adaptable aravis jacket ...
# Name: 160, dtype: object
# 161 id                                                           162
# description    astrid tank conjure up cardiff s shouldery wav...
# Name: 161, dtype: object
# 162 id                                                           163
# description    bandha dress boulder in this dress get married...
# Name: 162, dtype: object
# 163 id                                                           164
# description    bandha top this versatile top combines a strik...
# Name: 163, dtype: object
# 164 id                                                           165
# description    barely bikini better than going commando our p...
# Name: 164, dtype: object
# 165 id                                                           166
# description    better sweater jkt the better sweater jacket h...
# Name: 165, dtype: object
# 166 id                                                           167
# description    birdwalk t shirt temporarily grounded artist c...
# Name: 166, dtype: object
# 167 id                                                           168
# description    borderless capris unfazed by gloppy spindrift ...
# Name: 167, dtype: object
# 168 id                                                           169
# description    bouquet t shirt a garland of peacocks deer and...
# Name: 168, dtype: object
# 169 id                                                           170
# description    butterfly logo t shirt like monarchs the butte...
# Name: 169, dtype: object
# 170 id                                                           171
# description    cap bottoms made from our lightest weight capi...
# Name: 170, dtype: object
# 171 id                                                           172
# description    cap t shirt as good as a breeze to calm the sw...
# Name: 171, dtype: object
# 172 id                                                           173
# description    cap bottoms simul climbing the final pitches t...
# Name: 172, dtype: object
# 173 id                                                           174
# description    cap v neck the climber s choice capilene fabri...
# Name: 173, dtype: object
# 174 id                                                           175
# description    cap zip neck the bugaboos have long approaches...
# Name: 174, dtype: object
# 175 id                                                           176
# description    cap bottoms when your world consists of granit...
# Name: 175, dtype: object
# 176 id                                                           177
# description    dala horse t shirt originally fashioned from w...
# Name: 176, dtype: object
# 177 id                                                           178
# description    ditch the car ride t shirt the fun is in the g...
# Name: 177, dtype: object
# 178 id                                                           179
# description    down sweater there s much to see feet up at th...
# Name: 178, dtype: object
# 179 id                                                           180
# description    el cap jkt stuff the el cap jacket into your p...
# Name: 179, dtype: object
# 180 id                                                           181
# description    elsa top when shade seeking at nine palms star...
# Name: 180, dtype: object
# 181 id                                                           182
# description    elsa tunic the elsa tunic flourishes in heat p...
# Name: 181, dtype: object
# 182 id                                                           183
# description    gravitee tank the gravitee s racerback and ful...
# Name: 182, dtype: object
# 183 id                                                           184
# description    guide jkt sharp granite sticky verglas untrack...
# Name: 183, dtype: object
# 184 id                                                           185
# description    hills t shirt head for the hills wearing the s...
# Name: 184, dtype: object
# 185 id                                                           186
# description    inga shorts long rides continue after the sess...
# Name: 185, dtype: object
# 186 id                                                           187
# description    inter continental capris inter continental cap...
# Name: 186, dtype: object
# 187 id                                                           188
# description    inter continental pants long you ll like the f...
# Name: 187, dtype: object
# 188 id                                                           189
# description    island hemp pants a solid choice for evening h...
# Name: 188, dtype: object
# 189 id                                                           190
# description    island hemp skirt the island hemp skirt brings...
# Name: 189, dtype: object
# 190 id                                                           191
# description    island hemp top the breezy island hemp top tak...
# Name: 190, dtype: object
# 191 id                                                           192
# description    lithia dress celebrate the summer solstice wit...
# Name: 191, dtype: object
# 192 id                                                           193
# description    lithia pants pull out the lithia pants after y...
# Name: 192, dtype: object
# 193 id                                                           194
# description    lithia skirt after packing the quiver who has ...
# Name: 193, dtype: object
# 194 id                                                           195
# description    l s rashguard the upf fabric of our long sleev...
# Name: 194, dtype: object
# 195 id                                                           196
# description    l s runshade top long days and scorching rays ...
# Name: 195, dtype: object
# 196 id                                                           197
# description    m jkt made for those who thrive on thin and te...
# Name: 196, dtype: object
# 197 id                                                           198
# description    mandeville hoody a going places hoody the mand...
# Name: 197, dtype: object
# 198 id                                                           199
# description    margot dress dig the margot out of your board ...
# Name: 198, dtype: object
# 199 id                                                           200
# description    merino graphic t shirt feels as good as a laug...
# Name: 199, dtype: object
# 200 id                                                           201
# description    merino tank finespun and cool enough to lower ...
# Name: 200, dtype: object
# 201 id                                                           202
# description    merino crew be moved by the people and culture...
# Name: 201, dtype: object
# 202 id                                                           203
# description    merino dress stuff this flowing dress into you...
# Name: 202, dtype: object
# 203 id                                                           204
# description    micro puff vest too many alpine shiver fests c...
# Name: 203, dtype: object
# 204 id                                                           205
# description    morning glory capris our most versatile capris...
# Name: 204, dtype: object
# 205 id                                                           206
# description    morning glory cross back tank like a best frie...
# Name: 205, dtype: object
# 206 id                                                           207
# description    multi use shorts streamlined technical and ult...
# Name: 206, dtype: object
# 207 id                                                           208
# description    multi use skirt even while you re running unde...
# Name: 207, dtype: object
# 208 id                                                           209
# description    nine trails shorts mountain biking trail runni...
# Name: 208, dtype: object
# 209 id                                                           210
# description    nine trails vest simplicity in action this ves...
# Name: 209, dtype: object
# 210 id                                                           211
# description    r jkt a modern mountain staple the adaptable r...
# Name: 210, dtype: object
# 211 id                                                           212
# description    rain shadow jkt staying inside isn t the only ...
# Name: 211, dtype: object
# 212 id                                                           213
# description    rock guide pants our rock guides are made of a...
# Name: 212, dtype: object
# 213 id                                                           214
# description    rock guide shorts tough abrasion resistant roc...
# Name: 213, dtype: object
# 214 id                                                           215
# description    serenity tights long soft and stretchy for unr...
# Name: 214, dtype: object
# 215 id                                                           216
# description    simple guide jkt skin in by headlamp summit by...
# Name: 215, dtype: object
# 216 id                                                           217
# description    simple guide pants a trip to patagonia and one...
# Name: 216, dtype: object
# 217 id                                                           218
# description    sleeveless a c shirt as cooling but more struc...
# Name: 217, dtype: object
# 218 id                                                           219
# description    solid adour btm adours feature a scooped low r...
# Name: 218, dtype: object
# 219 id                                                           220
# description    solid betina btm our fullest coverage bottoms ...
# Name: 219, dtype: object
# 220 id                                                           221
# description    solid bibiana piece the sporty bibiana one pie...
# Name: 220, dtype: object
# 221 id                                                           222
# description    solid bibiana top the athletic bibiana top s r...
# Name: 221, dtype: object
# 222 id                                                           223
# description    solimar pants in case your travel plans coinci...
# Name: 222, dtype: object
# 223 id                                                           224
# description    solimar shorts horny toads and other professio...
# Name: 223, dtype: object
# 224 id                                                           225
# description    s s a c shirt not even stifling great basin he...
# Name: 224, dtype: object
# 225 id                                                           226
# description    s s rashguard the upf fabric of our short slee...
# Name: 225, dtype: object
# 226 id                                                           227
# description    s s sol patrol shirt a shirt impossible to ins...
# Name: 226, dtype: object
# 227 id                                                           228
# description    sun shelter shirt chic and sensible the sun sh...
# Name: 227, dtype: object
# 228 id                                                           229
# description    super cali shorts super cali shorts keep their...
# Name: 228, dtype: object
# 229 id                                                           230
# description    synch vest with the possible exception of duct...
# Name: 229, dtype: object
# 230 id                                                           231
# description    tranquila capri leggings even in the crux you ...
# Name: 230, dtype: object
# 231 id                                                           232
# description    traverse jkt the sun has set the air is cold a...
# Name: 231, dtype: object
# 232 id                                                           233
# description    undercover cami morph from water logged sea cr...
# Name: 232, dtype: object
# 233 id                                                           234
# description    vitaliti dress the ocean has had its way with ...
# Name: 233, dtype: object
# 234 id                                                           235
# description    vitaliti skirt after a long day at the sharp e...
# Name: 234, dtype: object
# 235 id                                                           236
# description    vitaliti tank whether it s sea spray river wat...
# Name: 235, dtype: object
# 236 id                                                           237
# description    wheat t shirt feeding urban and agrarian sensi...
# Name: 236, dtype: object
# 237 id                                                           238
# description    wyoming climbing poster max factor c vedauwoo ...
# Name: 237, dtype: object
# 238 id                                                           239
# description    yosemite essence t shirt artist phyllis shafer...
# Name: 238, dtype: object
# 239 id                                                           240
# description    print bayonne btm the low rise bayonne bottoms...
# Name: 239, dtype: object
# 240 id                                                           241
# description    print bibiana tankini the bibiana tankini s ra...
# Name: 240, dtype: object
# 241 id                                                           242
# description    print bibiana top the athletic bibiana top s r...
# Name: 241, dtype: object
# 242 id                                                           243
# description    print boucau halter top the boucau has soft ti...
# Name: 242, dtype: object
# 243 id                                                           244
# description    print kupala top our fixed triangle bikini top...
# Name: 243, dtype: object
# 244 id                                                           245
# description    runshade t shirt out in the backcountry or any...
# Name: 244, dtype: object
# 245 id                                                           246
# description    serenity capris for travelers committed to a c...
# Name: 245, dtype: object
# 246 id                                                           247
# description    serenity tights soft and stretchy for unrestri...
# Name: 246, dtype: object
# 247 id                                                           248
# description    simply organic polo like trumpeter swans the s...
# Name: 247, dtype: object
# 248 id                                                           249
# description    simply organic tank summer tanks take a beatin...
# Name: 248, dtype: object
# 249 id                                                           250
# description    simply organic tee the simply organic tee surv...
# Name: 249, dtype: object
# 250 id                                                           251
# description    simply organic top when spring s first blossom...
# Name: 250, dtype: object
# 251 id                                                           252
# description    solid boucau halter top the boucau has soft ti...
# Name: 251, dtype: object
# 252 id                                                           253
# description    solid kupala top our fixed triangle bikini top...
# Name: 252, dtype: object
# 253 id                                                           254
# description    solid paries btm the boy short style paries bo...
# Name: 253, dtype: object
# 254 id                                                           255
# description    solid sunamee btm stay put sunamees fit straig...
# Name: 254, dtype: object
# 255 id                                                           256
# description    solimar skirt the solimar is a brief and sassy...
# Name: 255, dtype: object
# 256 id                                                           257
# description    sol patrol shirt go ahead go bone fishing ride...
# Name: 256, dtype: object
# 257 id                                                           258
# description    sport top the loose performance fit of the wom...
# Name: 257, dtype: object
# 258 id                                                           259
# description    meridian board shorts the stretchy meridian bo...
# Name: 258, dtype: object
# 259 id                                                           260
# description    merino crew our lightest merino layer this sil...
# Name: 259, dtype: object
# 260 id                                                           261
# description    print paries btm styled like a boy short our p...
# Name: 260, dtype: object
# 261 id                                                           262
# description    print sunamee btm stay put sunamees fit straig...
# Name: 261, dtype: object
# 262 id                                                           263
# description    r full zip jkt it stretches breathes wicks and...
# Name: 262, dtype: object
# 263 id                                                           264
# description    r p o here s to trails that circle the globe a...
# Name: 263, dtype: object
# 264 id                                                           265
# description    merino t shirt so soft it s worth lingering in...
# Name: 264, dtype: object
# 265 id                                                           266
# description    merino bottoms thankfully dry and warm when yo...
# Name: 265, dtype: object
# 266 id                                                           267
# description    storm light jkt an emerging classic inspired b...
# Name: 266, dtype: object
# 267 id                                                           268
# description    stretch ascent jkt simple stretchy lightweight...
# Name: 267, dtype: object
# 268 id                                                           269
# description    merino t shirt our most versatile merino basel...
# Name: 268, dtype: object
# 269 id                                                           270
# description    merino pants these luxuriously soft pants have...
# Name: 269, dtype: object
# 270 id                                                           271
# description    morning glory dress when onshore winds blow ou...
# Name: 270, dtype: object
# 271 id                                                           272
# description    morning glory skirt you can stand still and wi...
# Name: 271, dtype: object
# 272 id                                                           273
# description    morning glory tights this everyday essential f...
# Name: 272, dtype: object
# 273 id                                                           274
# description    torrentshell jkt tropical rain forests share a...
# Name: 273, dtype: object
# 274 id                                                           275
# description    torrentshell pants they re lightweight waterpr...
# Name: 274, dtype: object
# 275 id                                                           276
# description    trampoli t shirt take your commute to higher g...
# Name: 275, dtype: object
# 276 id                                                           277
# description    cap zip neck keep your furnace stoked when tem...
# Name: 276, dtype: object
# 277 id                                                           278
# description    corinne dress after a day of rivermouth s glas...
# Name: 277, dtype: object
# 278 id                                                           279
# description    cotton fleece hoody when central coast nights ...
# Name: 278, dtype: object
# 279 id                                                           280
# description    nano puff p o the most versatile piece of insu...
# Name: 279, dtype: object
# 280 id                                                           281
# description    nine trails jkt the nine trails jacket is for ...
# Name: 280, dtype: object
# 281 id                                                           282
# description    down sweater vest impossible to confuse with t...
# Name: 281, dtype: object
# 282 id                                                           283
# description    drift shirt all epic tales of the west begin w...
# Name: 282, dtype: object
# 283 id                                                           284
# description    duway skirt everyone knows it s what s inside ...
# Name: 283, dtype: object
# 284 id                                                           285
# description    ester top throw on the ester top for a quick s...
# Name: 284, dtype: object
# 285 id                                                           286
# description    freedom to roam t shirt global warming and hab...
# Name: 285, dtype: object
# 286 id                                                           287
# description    girona board shorts evoking the spanish provin...
# Name: 286, dtype: object
# 287 id                                                           288
# description    north coast t shirt the north coast t shirt sp...
# Name: 287, dtype: object
# 288 id                                                           289
# description    owlin around t shirt the owlin around t shirt ...
# Name: 288, dtype: object
# 289 id                                                           290
# description    pinback top release your inner locomotion with...
# Name: 289, dtype: object
# 290 id                                                           291
# description    print adour btm adours have a slightly scooped...
# Name: 290, dtype: object
# 291 id                                                           292
# description    hotline top as your mind embraces the challeng...
# Name: 291, dtype: object
# 292 id                                                           293
# description    houdini full zip jkt now you see it now you do...
# Name: 292, dtype: object
# 293 id                                                           294
# description    inga shortie short boards and short shorts liv...
# Name: 293, dtype: object
# 294 id                                                           295
# description    vasana top the stretchy sleeveless vasana offe...
# Name: 294, dtype: object
# 295 id                                                           296
# description    versatili tee at the top of the t shirt food c...
# Name: 295, dtype: object
# 296 id                                                           297
# description    versatiliti cardi a summer weight cardigan for...
# Name: 296, dtype: object
# 297 id                                                           298
# description    versatiliti tank vivid colors and delicate det...
# Name: 297, dtype: object
# 298 id                                                           299
# description    active boy shorts we ve worn these versatile f...
# Name: 298, dtype: object
# 299 id                                                           300
# description    active briefs whether you re beating the heat ...
# Name: 299, dtype: object
# 300 id                                                           301
# description    active classic cami worn under a dry top or as...
# Name: 300, dtype: object
# 301 id                                                           302
# description    all time shell since rain is recycled we figur...
# Name: 301, dtype: object
# 302 id                                                           303
# description    all wear capris capris are more discreet than ...
# Name: 302, dtype: object
# ...
# description    retro grade shorts as advantageous as a number...
# Name: 399, dtype: object
# 400 id                                                           401
# description    reversible phone home travel broadly and surf ...
# Name: 400, dtype: object
# 401 id                                                           402
# description    river shorts river life is mighty fine but eve...
# Name: 401, dtype: object
# 402 id                                                           403
# description    hip pack entrusted with holding our essentials...
# Name: 402, dtype: object
# 403 id                                                           404
# description    hooded monk sweatshirt the sacred garment of p...
# Name: 403, dtype: object
# 404 id                                                           405
# description    houdini full zip jkt now you see it now you do...
# Name: 404, dtype: object
# 405 id                                                           406
# description    merino bottoms a stop and go pace like that of...
# Name: 405, dtype: object
# 406 id                                                           407
# description    merino crew in this soft long sleeved tee you ...
# Name: 406, dtype: object
# 407 id                                                           408
# description    baggies shorts summertime unwinds in a boister...
# Name: 407, dtype: object
# 408 id                                                           409
# description    boardie shorts let your grom rip tear and shre...
# Name: 408, dtype: object
# 409 id                                                           410
# description    sun glove take a look at an old flats guide s ...
# Name: 409, dtype: object
# 410 id                                                           411
# description    sun mask because sun protection only works if ...
# Name: 410, dtype: object
# 411 id                                                           412
# description    sunshade shirt this ultralight moisture wickin...
# Name: 411, dtype: object
# 412 id                                                           413
# description    cap crew jumping off rocks or over mud puddles...
# Name: 412, dtype: object
# 413 id                                                           414
# description    duality jkt like the spring weather in michiga...
# Name: 413, dtype: object
# 414 id                                                           415
# description    microburst jkt from the scottish highlands to ...
# Name: 414, dtype: object
# 415 id                                                           416
# description    micro puff vest too many alpine shiver fests c...
# Name: 415, dtype: object
# 416 id                                                           417
# description    micro d luxe cardigan a micro d luxe cardigan ...
# Name: 416, dtype: object
# 417 id                                                           418
# description    rashguard sanctuary from sun and chill alike t...
# Name: 417, dtype: object
# 418 id                                                           419
# description    sunshade hoody put an end to the sunscreen sta...
# Name: 418, dtype: object
# 419 id                                                           420
# description    riverwalker sticky high water slick bedrock co...
# Name: 419, dtype: object
# 420 id                                                           421
# description    freewheeler max like a storage locker on wheel...
# Name: 420, dtype: object
# 421 id                                                           422
# description    friction belt the wayfarer s belt lightweight ...
# Name: 421, dtype: object
# 422 id                                                           423
# description    future of the earth t shirt with the planet s ...
# Name: 422, dtype: object
# 423 id                                                           424
# description    torrentshell pants torrentshells open up the w...
# Name: 423, dtype: object
# 424 id                                                           425
# description    trim brim hat it s hard to improve on the halc...
# Name: 424, dtype: object
# 425 id                                                           426
# description    trucker hat mom and dad may remember when hats...
# Name: 425, dtype: object
# 426 id                                                           427
# description    gi ii zip off pants the multitalented gi ii zi...
# Name: 426, dtype: object
# 427 id                                                           428
# description    girl s baggies shorts an everyday staple for t...
# Name: 427, dtype: object
# 428 id                                                           429
# description    girl s beach skirt this easy to wear skirt har...
# Name: 428, dtype: object
# 429 id                                                           430
# description    mlc the secret to slipping through o hare s ga...
# Name: 429, dtype: object
# 430 id                                                           431
# description    mlc burrito ever show up at a confab looking l...
# Name: 430, dtype: object
# 431 id                                                           432
# description    girl s live simply deer t shirt soft wearing r...
# Name: 431, dtype: object
# 432 id                                                           433
# description    girl s live simply seal t shirt soft wearing r...
# Name: 432, dtype: object
# 433 id                                                           434
# description    girl s t back one piece a girl s trusted compa...
# Name: 433, dtype: object
# 434 id                                                           435
# description    girl s two piece set this lightweight two piec...
# Name: 434, dtype: object
# 435 id                                                           436
# description    lightwire sometimes you need to leave the offi...
# Name: 435, dtype: object
# 436 id                                                           437
# description    lightwire brief this adventure briefcase holds...
# Name: 436, dtype: object
# 437 id                                                           438
# description    guide jkt sharp granite sticky verglas untrack...
# Name: 437, dtype: object
# 438 id                                                           439
# description    guidewater duffle large whoever said getting t...
# Name: 438, dtype: object
# 439 id                                                           440
# description    cap bottoms the unwavering foundation for any ...
# Name: 439, dtype: object
# 440 id                                                           441
# description    cap crew capilene the most versatile and faste...
# Name: 440, dtype: object
# 441 id                                                           442
# description    cap bottoms ice climbers and alpinists know th...
# Name: 441, dtype: object
# 442 id                                                           443
# description    cap crew fundamental to the funhog lifestyle t...
# Name: 442, dtype: object
# 443 id                                                           444
# description    guidewater pants drift boat flats skiff spring...
# Name: 443, dtype: object
# 444 id                                                           445
# description    guidewater shirt it s a shirt it s a jacket it...
# Name: 444, dtype: object
# 445 id                                                           446
# description    cap zip neck our warmest synthetic baselayer f...
# Name: 445, dtype: object
# 446 id                                                           447
# description    caribou north wind t shirt akin to the north w...
# Name: 446, dtype: object
# 447 id                                                           448
# description    cerro torre one t shirt the interminable spiri...
# Name: 447, dtype: object
# 448 id                                                           449
# description    logo visor like a fortuitous cloud this visor ...
# Name: 448, dtype: object
# 449 id                                                           450
# description    long haul runners long hauls eat up backcountr...
# Name: 449, dtype: object
# 450 id                                                           451
# description    l s el ray shirt our most versatile sun shirt ...
# Name: 450, dtype: object
# 451 id                                                           452
# description    compound cargo pants short the ultimate do eve...
# Name: 451, dtype: object
# 452 id                                                           453
# description    compound cargo shorts with cargo pockets pulle...
# Name: 452, dtype: object
# 453 id                                                           454
# description    continental pants they go straight from a cram...
# Name: 453, dtype: object
# 454 id                                                           455
# description    guidewater waders king we built our guidewater...
# Name: 454, dtype: object
# 455 id                                                           456
# description    critical mass built for the two wheeled commut...
# Name: 455, dtype: object
# 456 id                                                           457
# description    mw hiking crew socks mount mendel s ice nine h...
# Name: 456, dtype: object
# 457 id                                                           458
# description    nano puff p o already a cult classic with our ...
# Name: 457, dtype: object
# 458 id                                                           459
# description    araveto zip jkt a slim fit and zip through sta...
# Name: 458, dtype: object
# 459 id                                                           460
# description    araveto hooded jkt for the deep chill of a fog...
# Name: 459, dtype: object
# 460 id                                                           461
# description    araveto jkt a hearty day spent running the sna...
# Name: 460, dtype: object
# 461 id                                                           462
# description    custodian pants reg the graveyard shift has it...
# Name: 461, dtype: object
# 462 id                                                           463
# description    custodian pants short the graveyard shift has ...
# Name: 462, dtype: object
# 463 id                                                           464
# description    daily grind this fully padded shoulder bag kee...
# Name: 463, dtype: object
# 464 id                                                           465
# description    baby baggies apron dress this lively dress kee...
# Name: 464, dtype: object
# 465 id                                                           466
# description    baby baggies shorts about of the planet is cov...
# Name: 465, dtype: object
# 466 id                                                           467
# description    baby circus t shirt animals of the savanna wor...
# Name: 466, dtype: object
# 467 id                                                           468
# description    guidewater waders reg we built our guidewater ...
# Name: 467, dtype: object
# 468 id                                                           469
# description    baby duality jkt reversibility and three seaso...
# Name: 468, dtype: object
# 469 id                                                           470
# description    baby live simply deer t shirt the live simply ...
# Name: 469, dtype: object
# 470 id                                                           471
# description    baby live simply seal t shirt swim fish haul o...
# Name: 470, dtype: object
# 471 id                                                           472
# description    double haul sometimes all you need is a single...
# Name: 471, dtype: object
# 472 id                                                           473
# description    down sweater there s much to see feet up at th...
# Name: 472, dtype: object
# 473 id                                                           474
# description    baby synch cardigan springtime temperatures fl...
# Name: 473, dtype: object
# 474 id                                                           475
# description    baby synch vest a baby s bouldering circuit in...
# Name: 474, dtype: object
# 475 id                                                           476
# description    baby tag you re it t shirt it s not fair they ...
# Name: 475, dtype: object
# 476 id                                                           477
# description    l s runshade top power pasta feed one last gea...
# Name: 476, dtype: object
# 477 id                                                           478
# description    l s sol patrol shirt two week boat trips in in...
# Name: 477, dtype: object
# 478 id                                                           479
# description    bimini cap south of kanab temperatures take a ...
# Name: 478, dtype: object
# 479 id                                                           480
# description    borderless messenger shorts pair these lightwe...
# Name: 479, dtype: object
# 480 id                                                           481
# description    duck pants reg essential wear for splitting lo...
# Name: 480, dtype: object
# 481 id                                                           482
# description    duck pants short essential wear for splitting ...
# Name: 481, dtype: object
# 482 id                                                           483
# description    duck shorts sometimes life requires a welder o...
# Name: 482, dtype: object
# 483 id                                                           484
# description    borderless trek pants the ruby crest trail run...
# Name: 483, dtype: object
# 484 id                                                           485
# description    borderless trek zip off pants made for technic...
# Name: 484, dtype: object
# 485 id                                                           486
# description    half mass sized for riding a bike and finely t...
# Name: 485, dtype: object
# 486 id                                                           487
# description    cap crew when it comes to moisture this long s...
# Name: 486, dtype: object
# 487 id                                                           488
# description    cap graphic crew the choice for rest days that...
# Name: 487, dtype: object
# 488 id                                                           489
# description    fitz roy study t shirt when unveiled the fitzr...
# Name: 488, dtype: object
# 489 id                                                           490
# description    flyfishing the athabasca poster patrik ondrus ...
# Name: 489, dtype: object
# 490 id                                                           491
# description    flying fish t shirt life s more colorful with ...
# Name: 490, dtype: object
# 491 id                                                           492
# description    freedom to roam t shirt global warming and hab...
# Name: 491, dtype: object
# 492 id                                                           493
# description     logo t shirt patagonia s timeless logo t shir...
# Name: 492, dtype: object
# 493 id                                                           494
# description    active boxer briefs a no fuss travel companion...
# Name: 493, dtype: object
# 494 id                                                           495
# description    active briefs these featherweight quick wickin...
# Name: 494, dtype: object
# 495 id                                                           496
# description    cap bottoms cut loose from the maddening crowd...
# Name: 495, dtype: object
# 496 id                                                           497
# description    cap crew this crew takes the edge off fickle w...
# Name: 496, dtype: object
# 497 id                                                           498
# description    all time shell no need to use that morning tim...
# Name: 497, dtype: object
# 498 id                                                           499
# description    all wear cargo shorts all wear cargo shorts ba...
# Name: 498, dtype: object
# 499 id                                                           500
# description    all wear shorts time to simplify our all wear ...
# Name: 499, dtype: object

# %%
results
# { id : [(similarity, id)], ...}
# Out:
# {1: [(0.1998035147475983, 19),
#   (0.15182409328775237, 18),
#   (0.14951420049273145, 494),
#   (0.14806033056097512, 172),
#   (0.13030126898051572, 442),
#   (0.1243423196112318, 495),
#   (0.12392584918794144, 171),
#   (0.12147764628515076, 496),
#   (0.12115585151508487, 21),
#   (0.11808451510781004, 25),
#   (0.11504658905198849, 487),
#   (0.11235479373851076, 20),
#   (0.1118327275919725, 340),
#   (0.10959808513484064, 341),
#   (0.10692528247679021, 488),
#   (0.10614125580266508, 176),
#   (0.10207387829377773, 440),
#   (0.09777843752722717, 60),
#   (0.09748273457862415, 497),
#   (0.09359390250402862, 441),
#   (0.09317238064140862, 413),
#   (0.09293701129609476, 173),
#   (0.08994786659969368, 443),
#   (0.08983693442710128, 174),
#   (0.0856473126572201, 359),
#   (0.08559224675918581, 22),
#   (0.08406462778023249, 23),
#   (0.0839371084729726, 61),
#   (0.08381729893691749, 365),
#   (0.08208667249888199, 360),
#   (0.08188555763627496, 175),
#   (0.079568083310144, 24),
#   (0.07953567521275805, 2),
#   (0.07927542874833748, 406),
#   (0.07183542695626735, 266),
#   (0.06921520609323353, 277),
#   (0.06497423618614116, 446),
#   (0.06445968130871964, 312),
#   (0.06313762238516597, 329),
#   (0.060355542112350696, 34),
#   (0.058511036315081234, 326),
#   (0.057862664741124226, 358),
#   (0.05764187597158345, 450),
#   (0.05604682176946931, 328),
#   (0.05234966954740823, 324),
#   (0.05217409396709797, 451),
#   (0.05105274993386456, 331),
#   (0.05075532631409216, 330),
#   (0.050512196275038376, 259),
#   (0.050161467476534174, 57),
#   (0.0499621058785101, 92),
#   (0.04817021886498823, 147),
#   (0.047825204938058995, 40),
#   (0.04763792953929727, 62),
#   (0.04688440358285701, 303),
#   (0.04662316036049055, 214),
#   (0.04617258350532002, 88),
#   (0.04576309589934645, 12),
#   (0.04561033190764228, 168),
#   (0.045321917261286856, 272),
#   (0.04521624208282905, 193),
#   (0.04498908717286672, 260),
#   (0.04497652250187195, 3),
#   (0.04478541017340341, 469),
#   (0.044605418227482735, 164),
#   (0.04437488296819256, 392),
#   (0.044288911170086376, 391),
#   (0.04427009677873288, 100),
#   (0.04424449196857932, 110),
#   (0.04422976317753282, 265),
#   (0.043989564198669985, 419),
#   (0.043759119749476744, 195),
#   (0.04358931173976565, 414),
#   (0.04350522897164385, 200),
#   (0.043389658544693725, 201),
#   (0.043360025843667445, 105),
#   (0.042566214008042474, 87),
#   (0.04256234662694931, 209),
#   (0.042448738806494725, 223),
#   (0.04238724669732754, 202),
#   (0.042139070601674294, 180),
#   (0.04193536721418847, 146),
#   (0.04187240415880727, 287),
#   (0.041763614321015136, 407),
#   (0.0416985396125579, 90),
#   (0.041556193316343186, 205),
#   (0.041551093382796556, 89),
#   (0.04103545261689518, 76),
#   (0.04099200724280022, 325),
#   (0.04061972310221232, 30),
#   (0.040495583557550445, 29),
#   (0.04035026258252526, 499),
#   (0.04016177028094231, 163),
#   (0.039598249086049885, 213),
#   (0.03947163743645767, 306),
#   (0.03932373107519838, 125),
#   (0.03893257327281862, 301),
#   (0.03888191183888122, 466)],
#  2: [(0.31857781739114144, 3),
#   (0.10938271159683842, 300),
#   (0.10095608662292796, 494),
#   (0.0965251556316986, 19),
#   (0.07953567521275805, 1),
#   (0.07934735702820463, 318),
#   (0.07888972807515723, 299),
#   (0.07518863715752065, 155),
#   (0.06947361266991807, 18),
#   (0.06680007733992198, 495),
#   (0.06634890924381742, 165),
#   (0.06408364264462046, 301),
#   (0.06362444288147222, 450),
#   (0.06289740395284568, 156),
#   (0.06151337068553859, 164),
#   (0.06110035662864591, 258),
#   (0.06030856132556796, 328),
#   (0.059951090195872345, 496),
#   (0.05940369691018719, 214),
#   (0.05915618800267672, 273),
#   (0.05765783412743294, 173),
#   (0.05414532867698095, 205),
#   (0.053590991644660385, 330),
#   (0.05289929338930088, 168),
#   (0.05174730672721134, 329),
#   (0.05159300714858278, 259),
#   (0.0507066840842573, 62),
#   (0.05028587858647604, 324),
#   (0.04932830639762938, 272),
#   (0.04887238834666437, 287),
#   (0.048172620640612, 411),
#   (0.047902531695072643, 146),
#   (0.04757074431009544, 213),
#   (0.047323008930354384, 11),
#   (0.046946868882696544, 209),
#   (0.0445837520718933, 115),
#   (0.044534481044729256, 419),
#   (0.04448003750234523, 61),
#   (0.04428518933882506, 326),
#   (0.04425877863920593, 306),
#   (0.043777711991494044, 413),
#   (0.043495173651467156, 485),
#   (0.04321674040811318, 187),
#   (0.0432156544727448, 23),
#   (0.04301661655730125, 417),
#   (0.04297643636657853, 316),
#   (0.04291452000472706, 499),
#   (0.04228616499239142, 442),
#   (0.041798781740646454, 223),
#   (0.041754408466614656, 25),
#   (0.04115484495810101, 157),
#   (0.041137815009233455, 159),
#   (0.04112132641959741, 353),
#   (0.041012211785669744, 497),
#   (0.040983806393923496, 365),
#   (0.04065546995854444, 440),
#   (0.04057936654399601, 4),
#   (0.04055286050807739, 22),
#   (0.04046694152973149, 147),
#   (0.0404585544018514, 303),
#   (0.04022058291516116, 16),
#   (0.039329449876259304, 34),
#   (0.039145032934112756, 331),
#   (0.03861967275225677, 175),
#   (0.03857293185122718, 359),
#   (0.03848684517371172, 312),
#   (0.03847661516279517, 360),
#   (0.03830736126736095, 171),
#   (0.037745260191638715, 193),
#   (0.03772568385110925, 15),
#   (0.03758452727412336, 317),
#   (0.03749973322505533, 406),
#   (0.03736326368570981, 480),
#   (0.03727853086857241, 343),
#   (0.037235255579162824, 395),
#   (0.037230880870003175, 412),
#   (0.037073926734091434, 402),
#   (0.036879919237328924, 92),
#   (0.03650905886677477, 381),
#   (0.036480397582814, 266),
#   (0.03644631010784973, 308),
#   (0.03632556854953653, 5),
#   (0.035828870470184515, 105),
#   (0.03576201090367174, 52),
#   (0.03544531224970577, 97),
#   (0.03531696808523752, 454),
#   (0.035295082384381206, 174),
#   (0.03518225851042454, 384),
#   (0.03502608668184715, 441),
#   (0.03499244383202729, 277),
#   (0.03472018742978477, 163),
#   (0.03454952724073247, 176),
#   (0.03433867307502455, 427),
#   (0.03428358721941864, 484),
#   (0.03413076304164049, 290),
#   (0.03410827495005392, 100),
#   (0.034083368036692686, 12),
#   (0.03372088622877947, 217)],
#  3: [(0.31857781739114144, 2),
#   (0.11099661801832685, 300),
#   (0.1096233432180915, 495),
#   (0.09190102017605901, 155),
#   (0.08602278558849731, 165),
#   (0.08399070131427895, 318),
#   (0.08017734610631326, 299),
#   (0.0798040018258044, 156),
#   (0.07614556815314279, 494),
#   (0.07012421257512848, 164),
#   (0.0691289234222809, 62),
#   (0.06800216644161688, 258),
#   (0.06770673207623594, 328),
#   (0.06624091774129419, 11),
#   (0.06201239388196241, 316),
#   (0.05958733035357659, 22),
#   (0.057103775375050445, 419),
#   (0.05597490348765068, 450),
#   (0.0525616277235311, 496),
#   (0.05221452783571845, 359),
#   (0.052067049664017484, 497),
#   (0.05163047872160071, 413),
#   (0.05096371073569934, 106),
#   (0.05080894691118045, 25),
#   (0.050442035989896175, 301),
#   (0.05034711799015857, 259),
#   (0.04983337877165287, 19),
#   (0.049486278432944564, 174),
#   (0.049401485956656825, 236),
#   (0.049243346735457834, 472),
#   (0.049079270632890845, 360),
#   (0.048219691753329935, 23),
#   (0.048005272005208405, 412),
#   (0.047968832781285074, 326),
#   (0.04782697002563681, 272),
#   (0.04778170967545733, 264),
#   (0.047652853843231126, 176),
#   (0.047566987270665925, 55),
#   (0.04715262585350881, 209),
#   (0.04662714578590499, 434),
#   (0.04654714545361232, 317),
#   (0.045606206790028296, 16),
#   (0.04535995425063318, 52),
#   (0.04535478958173508, 45),
#   (0.04513070251493014, 105),
#   (0.04497652250187195, 1),
#   (0.04484563763206888, 378),
#   (0.04483894403050232, 12),
#   (0.044792196171140476, 417),
#   (0.04434307453078465, 173),
#   (0.04426084083811777, 263),
#   (0.04420718493837123, 329),
#   (0.044176299355606, 331),
#   (0.0437754678851713, 398),
#   (0.04369140095581719, 418),
#   (0.04343557206752226, 287),
#   (0.04341793730527721, 444),
#   (0.04336445738268083, 277),
#   (0.043076100284835155, 57),
#   (0.04291273509010488, 488),
#   (0.042895397469470666, 442),
#   (0.042330370901504114, 290),
#   (0.042159443052841035, 136),
#   (0.04203483060388873, 408),
#   (0.04200937561225634, 330),
#   (0.04199076441946831, 175),
#   (0.04194015368977118, 61),
#   (0.04180250400448431, 446),
#   (0.04153931783223219, 308),
#   (0.04140170384740107, 5),
#   (0.0413255575947667, 168),
#   (0.04096378687869929, 76),
#   (0.04092879170487262, 163),
#   (0.04031153368487908, 441),
#   (0.039880321079514704, 383),
#   (0.03986116389953586, 82),
#   (0.03925960265207824, 478),
#   (0.03912840634969851, 183),
#   (0.038771327624496185, 445),
#   (0.03872744128140451, 125),
#   (0.03858628964589336, 380),
#   (0.03854290288139772, 201),
#   (0.03850833491928252, 147),
#   (0.03842749746390276, 362),
#   (0.03829876262082961, 443),
#   (0.03821604939688623, 218),
#   (0.038182445685749314, 114),
#   (0.03793499710306356, 260),
#   (0.037637385218010216, 440),
#   (0.037593679422889235, 283),
#   (0.03730967393874659, 353),
#   (0.03729473175487821, 265),
#   (0.03716440481154139, 200),
#   (0.03705386797350306, 292),
#   (0.036707936714296806, 7),
#   (0.03670244119065934, 4),
#   (0.03661346859508721, 113),
#   (0.036541830998094084, 159)],
#  4: [(0.8351414376247674, 159),
#   (0.16474625945782984, 184),
#   (0.156167793020157, 343),
#   (0.14746231417945072, 379),
#   (0.14593902929010988, 384),
#   (0.13905590930083445, 438),
#   (0.1365531424671746, 353),
#   (0.12497412026276396, 331),
#   (0.12457991446437675, 216),
#   (0.12309600542312198, 120),
#   (0.11495459449275337, 213),
#   (0.11466893466835829, 115),
#   (0.11049894435583775, 217),
#   (0.10358731526696428, 86),
#   (0.10062114972144341, 214),
#   (0.09875461188110432, 232),
#   (0.09653116080055119, 387),
#   (0.09602519439157885, 268),
#   (0.09399399034080841, 349),
#   (0.09118558429170345, 187),
#   (0.0909746346380915, 302),
#   (0.0893049369266545, 143),
#   (0.08828640406405736, 188),
#   (0.08812401725269771, 305),
#   (0.08649608864691284, 308),
#   (0.08620953913064293, 5),
#   (0.08474237326806981, 306),
#   (0.08418120193544039, 6),
#   (0.07846598915958464, 414),
#   (0.07822040193005796, 210),
#   (0.0777575891318261, 364),
#   (0.07495307979960802, 96),
#   (0.07238084999154729, 469),
#   (0.07144243685323881, 223),
#   (0.07099651904409138, 281),
#   (0.06907507283842514, 416),
#   (0.06740495103120973, 209),
#   (0.0664337841313188, 328),
#   (0.06618590005393435, 352),
#   (0.06613841323265844, 204),
#   (0.06589289000365828, 212),
#   (0.06554419543199193, 402),
#   (0.06544953328277767, 454),
#   (0.06470184293979592, 382),
#   (0.06463978046257204, 329),
#   (0.06460770298837919, 403),
#   (0.06307862496328139, 207),
#   (0.0628792368070876, 141),
#   (0.06279059499018365, 444),
#   (0.06257938251089798, 275),
#   (0.06252836765653659, 473),
#   (0.06240419081555847, 97),
#   (0.062317034350157036, 280),
#   (0.061359218553998715, 498),
#   (0.06133456749585846, 35),
#   (0.061271090518338366, 33),
#   (0.06110635599103647, 15),
#   (0.060873137252921, 224),
#   (0.06081626033575783, 16),
#   (0.06033733823615848, 415),
#   (0.06002930207811922, 29),
#   (0.05970958765466575, 52),
#   (0.05940295137271946, 179),
#   (0.059158732592987165, 46),
#   (0.058881227027944, 55),
#   (0.058736910359118946, 485),
#   (0.05866663582393518, 100),
#   (0.05839910218515926, 445),
#   (0.05730477535003518, 480),
#   (0.057020238175882455, 472),
#   (0.05680186834272652, 330),
#   (0.0566046038897827, 450),
#   (0.056534486647346664, 45),
#   (0.0562149990785322, 107),
#   (0.0562149990785322, 351),
#   (0.05615212724997834, 59),
#   (0.0554763809421563, 293),
#   (0.054985031987791325, 458),
#   (0.054171370510736255, 284),
#   (0.05414458645952997, 168),
#   (0.0538710607250386, 381),
#   (0.053817150389927286, 7),
#   (0.053601156845034005, 405),
#   (0.053163895707086156, 208),
#   (0.05293653012796155, 386),
#   (0.05288871427016168, 409),
#   (0.052463462960318494, 267),
#   (0.051705341143612714, 259),
#   (0.05112198244322278, 287),
#   (0.050176874085344124, 211),
#   (0.04957793005294502, 424),
#   (0.049531572998008366, 25),
#   (0.0493350246012467, 256),
#   (0.048289376133536996, 464),
#   (0.047904755196059, 389),
#   (0.04753829636101621, 112),
#   (0.04730560208254834, 484),
#   (0.04723534550759952, 57)],
#  5: [(0.9533791878630138, 308),
#   (0.1713833147616277, 96),
#   (0.16818288784359794, 281),
#   (0.1377555268081818, 364),
#   (0.13694017292245556, 210),
#   (0.12799725982694068, 204),
#   (0.12571788532795836, 469),
#   (0.12527930504838442, 97),
#   (0.12229528419391314, 293),
#   (0.1222019355192248, 209),
#   (0.120807552429612, 216),
#   (0.11978283022868175, 120),
#   (0.11908276801724474, 416),
#   (0.11808682803359295, 207),
#   (0.11672302958925114, 438),
#   (0.11668112553563637, 184),
#   (0.11420816186740354, 450),
#   (0.11337526728005162, 414),
#   (0.10844749805440781, 473),
#   (0.1078732030540682, 35),
#   (0.10753123477376439, 232),
#   (0.10591957746057133, 331),
#   (0.1018182587241718, 143),
#   (0.10121587952232135, 353),
#   (0.10000512006509649, 498),
#   (0.09937976123778904, 179),
#   (0.09911612642029681, 280),
#   (0.09653285890439794, 217),
#   (0.0952386683349847, 405),
#   (0.0951769719027786, 147),
#   (0.09497775564202254, 208),
#   (0.09463193479903124, 302),
#   (0.09190355840648197, 6),
#   (0.09079983645732306, 117),
#   (0.08998443960348909, 386),
#   (0.08932074919072032, 267),
#   (0.08878045357665018, 348),
#   (0.08707156636403525, 403),
#   (0.08682144318499074, 159),
#   (0.08620953913064293, 4),
#   (0.08548258053592775, 458),
#   (0.08452592830678625, 415),
#   (0.08395596650695371, 245),
#   (0.08340963255312132, 282),
#   (0.08126604254873342, 387),
#   (0.08084008799293213, 268),
#   (0.0806158623583375, 306),
#   (0.07933805687591074, 379),
#   (0.07915100625080851, 477),
#   (0.07901629878416089, 384),
#   (0.07565867877609406, 402),
#   (0.07311347305178494, 82),
#   (0.07294572195721084, 424),
#   (0.07275194949949632, 115),
#   (0.07228479918210341, 188),
#   (0.07224869655636763, 196),
#   (0.07215184441773863, 305),
#   (0.07205560003169492, 187),
#   (0.07160434615625333, 12),
#   (0.0700068570373897, 382),
#   (0.06917014575150465, 100),
#   (0.06911043828256988, 408),
#   (0.06884405472905715, 274),
#   (0.06884405472905715, 327),
#   (0.06857864521349745, 380),
#   (0.06841966984604653, 214),
#   (0.06792292201262992, 212),
#   (0.06769430912628231, 7),
#   (0.0672989239374861, 343),
#   (0.06602164854643346, 104),
#   (0.06441971420157518, 45),
#   (0.0637368397393023, 312),
#   (0.06256401749628814, 105),
#   (0.06238737152339505, 33),
#   (0.062152548895523525, 381),
#   (0.0616469217831005, 445),
#   (0.0610382593470083, 85),
#   (0.060599680442247394, 428),
#   (0.060513660753896636, 141),
#   (0.06022508725846943, 275),
#   (0.06001683551622093, 213),
#   (0.05949655107060338, 153),
#   (0.059492371580377075, 154),
#   (0.059484884032836596, 367),
#   (0.05946947625381823, 355),
#   (0.0593469421756915, 67),
#   (0.059143054241136424, 284),
#   (0.05847939180384891, 197),
#   (0.05834202980055158, 55),
#   (0.05794709743181024, 93),
#   (0.05763908300854847, 352),
#   (0.0573541670208809, 351),
#   (0.0573541670208809, 107),
#   (0.05701237763432819, 51),
#   (0.05672916609494618, 53),
#   (0.055862846938576946, 15),
#   (0.055667663088025635, 454),
#   (0.05552377145763229, 211)],
#  6: [(0.2949311729450838, 438),
#   (0.2913347356878658, 184),
#   (0.1792964920717045, 382),
#   (0.15051520725656428, 415),
#   (0.14037054130457857, 212),
#   (0.13164742028134235, 387),
#   (0.13095739260594894, 268),
#   (0.11920915399530112, 216),
#   (0.11591124596412722, 120),
#   (0.10934854511827646, 302),
#   (0.09916218672247912, 85),
#   (0.09834982367135658, 197),
#   (0.09653381475749871, 308),
#   (0.09642938785916928, 232),
#   (0.09535584679185195, 267),
#   (0.09527998388886774, 386),
#   (0.09269610647238544, 217),
#   (0.09190355840648197, 5),
#   (0.08974845953330175, 353),
#   (0.0873295569342828, 469),
#   (0.08476649849715596, 143),
#   (0.08458710447005251, 327),
#   (0.08458710447005251, 274),
#   (0.08418120193544039, 4),
#   (0.08102568115566487, 331),
#   (0.08011221764005903, 384),
#   (0.07926453114869049, 35),
#   (0.07701918662095511, 354),
#   (0.07556953937554035, 159),
#   (0.07500061983265506, 379),
#   (0.07469478207354599, 306),
#   (0.07456852561861704, 82),
#   (0.07354104107408886, 472),
#   (0.0728532855506839, 55),
#   (0.07255886254346905, 204),
#   (0.07197574390178428, 293),
#   (0.06978013906537008, 416),
#   (0.06952732023148811, 414),
#   (0.06931355137299283, 498),
#   (0.06911260547601107, 280),
#   (0.0669284490325424, 207),
#   (0.06672723965693694, 209),
#   (0.06636522043205954, 389),
#   (0.0663013391885062, 115),
#   (0.06622664220907558, 405),
#   (0.0650832438037159, 380),
#   (0.06398930996732305, 188),
#   (0.06387161324927387, 305),
#   (0.063523464670532, 464),
#   (0.06331847440340313, 281),
#   (0.063075410004812, 96),
#   (0.0625191677688995, 51),
#   (0.062135481227084004, 436),
#   (0.062017950247569786, 97),
#   (0.061994794102828495, 445),
#   (0.06175559291154128, 284),
#   (0.06051969325628753, 437),
#   (0.060006332029656266, 15),
#   (0.05947074230590215, 458),
#   (0.05894181880777976, 403),
#   (0.05889736958713658, 378),
#   (0.05885463239654534, 343),
#   (0.058129335175645086, 263),
#   (0.057950941412934116, 187),
#   (0.05744396523915216, 473),
#   (0.05737494552969966, 208),
#   (0.05688661154139372, 275),
#   (0.056423135007551785, 141),
#   (0.05635309556495097, 368),
#   (0.05581779461661854, 83),
#   (0.05546251239217729, 352),
#   (0.05507606141730623, 29),
#   (0.054958469135168116, 105),
#   (0.05445116346482608, 364),
#   (0.05418525801394725, 211),
#   (0.05310661659797119, 480),
#   (0.053106096911844244, 328),
#   (0.05304791569560456, 210),
#   (0.05290993265971324, 31),
#   (0.052684003457287826, 330),
#   (0.05264637847538631, 62),
#   (0.0523738559219443, 485),
#   (0.05177678116630521, 179),
#   (0.051471550152107734, 466),
#   (0.05109354407461089, 59),
#   (0.05099716657891043, 33),
#   (0.05064632201689494, 161),
#   (0.05035018721257446, 381),
#   (0.050155240709845436, 282),
#   (0.04984848194795202, 402),
#   (0.049690130085276014, 157),
#   (0.049636503060462425, 84),
#   (0.04952479541429215, 455),
#   (0.049210695080473904, 408),
#   (0.04920773987071621, 168),
#   (0.04919936962497805, 395),
#   (0.04909158054428121, 468),
#   (0.049059256354321464, 484)],
#  7: [(0.23460249560222216, 354),
#   (0.22787528113787137, 104),
#   (0.21767461560143433, 464),
#   (0.20598277839155324, 403),
#   (0.20226564527234486, 393),
#   (0.198398660388269, 437),
#   (0.19220169586541247, 436),
#   (0.17703464749487546, 31),
#   (0.13995294805856792, 456),
#   (0.13142377562147023, 131),
#   (0.12848235524728296, 389),
#   (0.1272349922176731, 486),
#   (0.12556158233499062, 93),
#   (0.12303186031762696, 430),
#   (0.12194756386363902, 368),
#   (0.11718450018094743, 431),
#   (0.11149112604097408, 472),
#   (0.10937229468805436, 94),
#   (0.1047206945581715, 394),
#   (0.09662674816386936, 55),
#   (0.09156780767273398, 84),
#   (0.08786190652315957, 439),
#   (0.08504753847688369, 50),
#   (0.08132460989880823, 83),
#   (0.07898545376685769, 210),
#   (0.07881234889099768, 42),
#   (0.07851811432630947, 364),
#   (0.07728860118515805, 421),
#   (0.06847301568391687, 120),
#   (0.06769430912628231, 5),
#   (0.06767397448690311, 130),
#   (0.06734868266043466, 308),
#   (0.06544987046655276, 438),
#   (0.06513179777168754, 217),
#   (0.06449494058076544, 216),
#   (0.06383117760923704, 134),
#   (0.0634039278692401, 143),
#   (0.06275347443998623, 204),
#   (0.06253618131483997, 473),
#   (0.06219127653084811, 35),
#   (0.061495053449891084, 353),
#   (0.061279225682835795, 416),
#   (0.060831892851237857, 232),
#   (0.06000471654716233, 49),
#   (0.05906248937385297, 184),
#   (0.05748162110122522, 96),
#   (0.05733286814056767, 402),
#   (0.056779765837072275, 179),
#   (0.05654405069707668, 281),
#   (0.055697944408421324, 306),
#   (0.05507081758380668, 282),
#   (0.05447626627611881, 379),
#   (0.053817150389927286, 4),
#   (0.053207670458508945, 159),
#   (0.05301291950505269, 13),
#   (0.05262424105243631, 209),
#   (0.0524050790885505, 97),
#   (0.05237136204708045, 214),
#   (0.0521522517553076, 187),
#   (0.05126427052337982, 331),
#   (0.05089118635766454, 384),
#   (0.05036051621717174, 188),
#   (0.050267887190838315, 305),
#   (0.04868072840071545, 302),
#   (0.048314927912100646, 275),
#   (0.04814639278472403, 12),
#   (0.0478616908396429, 53),
#   (0.04742587980050081, 6),
#   (0.046680379864724085, 267),
#   (0.04654281908448047, 387),
#   (0.04646838290891359, 445),
#   (0.04629886570362057, 268),
#   (0.04572144714367657, 408),
#   (0.045528268102473374, 450),
#   (0.04519818645070227, 70),
#   (0.04501345597559398, 343),
#   (0.04486302771366289, 43),
#   (0.04450364539438485, 386),
#   (0.04433473177215719, 100),
#   (0.043809156128650606, 280),
#   (0.043107557658201553, 115),
#   (0.042938588652009085, 498),
#   (0.042460637743182185, 458),
#   (0.042349579870023406, 454),
#   (0.04112657852996158, 455),
#   (0.04100327255992218, 141),
#   (0.04084503228915511, 153),
#   (0.040842163023455294, 154),
#   (0.04083702274026989, 367),
#   (0.040826445131649125, 355),
#   (0.04067754529996595, 342),
#   (0.040582769393493506, 468),
#   (0.0394833416059588, 213),
#   (0.039407890237478906, 208),
#   (0.03939923850737107, 349),
#   (0.03906908068784806, 312),
#   (0.03872201031964796, 284),
#   (0.03862412885383116, 10)],
#  8: [(0.8860830538051045, 220),
#   (0.2778964658600861, 262),
#   (0.2739890546041937, 255),
#   (0.2328970669568295, 291),
#   (0.21456556224844978, 240),
#   (0.21413133933807244, 219),
#   (0.19013608002250673, 261),
#   (0.17762965877953196, 254),
#   (0.13863555423487975, 221),
#   (0.11554377637655111, 241),
#   (0.09273522435923928, 242),
#   (0.09053734943208089, 222),
#   (0.08604780828371036, 243),
#   (0.08396876336827112, 252),
#   (0.0751228761463068, 244),
#   (0.07276204907344905, 253),
#   (0.06479161122942387, 429),
#   (0.044826290398974906, 301),
#   (0.04396252472369766, 435),
#   (0.042356093459738606, 164),
#   (0.04181508541207991, 434),
#   (0.041612239072416415, 258),
#   (0.03928057974871414, 299),
#   (0.0361475448962198, 273),
#   (0.035118811371415704, 231),
#   (0.03340969355127712, 272),
#   (0.03262002885030135, 188),
#   (0.032560030229589414, 305),
#   (0.03253885559026398, 206),
#   (0.032197706170838516, 156),
#   (0.03206207891822599, 224),
#   (0.032040071978701644, 187),
#   (0.031956678270432984, 341),
#   (0.0317621648876474, 155),
#   (0.031201729823856033, 329),
#   (0.030052629111597274, 183),
#   (0.0300367385799835, 223),
#   (0.029682834328494827, 214),
#   (0.02955189250979223, 195),
#   (0.029390686979894755, 383),
#   (0.028744201071236566, 385),
#   (0.028663003499248177, 300),
#   (0.0273781727384588, 165),
#   (0.027335467645726922, 330),
#   (0.027286548827928213, 328),
#   (0.026403609846214517, 247),
#   (0.026205982693351896, 215),
#   (0.02577703217070073, 271),
#   (0.025688785918037103, 205),
#   (0.025651934087287234, 418),
#   (0.02512383036003524, 168),
#   (0.024856069786896213, 485),
#   (0.024527822843168744, 148),
#   (0.024096069865219196, 163),
#   (0.023695826150804747, 484),
#   (0.023688290431738077, 278),
#   (0.02351825162905282, 158),
#   (0.022865851667986704, 115),
#   (0.022303136726996395, 226),
#   (0.022017017153299526, 339),
#   (0.02153138766839582, 312),
#   (0.020829307032337405, 16),
#   (0.020817739626690843, 295),
#   (0.020638782777454047, 480),
#   (0.020037204557680044, 306),
#   (0.01985551396338221, 246),
#   (0.019456747748142243, 15),
#   (0.018845775393930512, 96),
#   (0.01881040146335772, 208),
#   (0.01853838598990755, 281),
#   (0.018157881623755628, 213),
#   (0.0181030139651048, 304),
#   (0.018086979714574875, 77),
#   (0.018068182741585816, 361),
#   (0.01730298494689897, 395),
#   (0.017274470067851714, 75),
#   (0.017218660259399672, 324),
#   (0.016858301239634676, 11),
#   (0.01680880115787026, 290),
#   (0.01671600869899555, 55),
#   (0.016631848592929852, 292),
#   (0.016601779516448083, 59),
#   (0.016542170507096787, 365),
#   (0.016320522008535968, 388),
#   (0.01623437075680859, 162),
#   (0.016184646257415322, 210),
#   (0.016173716295627975, 81),
#   (0.016123125519654447, 157),
#   (0.0160888852892029, 364),
#   (0.016075647396160606, 80),
#   (0.016005838516104546, 338),
#   (0.015930863570328996, 270),
#   (0.015786338837200795, 343),
#   (0.01573948849199446, 410),
#   (0.015649701287417446, 92),
#   (0.015469385026852814, 457),
#   (0.015449576410268397, 232),
#   (0.015415356413457792, 203)],
#  9: [(0.28827815883714797, 417),
#   (0.10791758270299018, 469),
#   (0.10281923333865219, 459),
#   (0.09632111987625272, 475),
#   (0.09516628086483167, 474),
#   (0.09225703025685014, 230),
#   (0.08214644399323191, 461),
#   (0.08148700091631442, 414),
#   (0.08077715748160641, 460),
#   (0.06951139403903754, 66),
#   (0.06921405520158601, 320),
#   (0.06865234959652604, 321),
#   (0.06861740733098771, 248),
#   (0.06726236023523438, 180),
#   (0.06445185121811614, 216),
#   (0.06272602331200826, 279),
#   (0.06229497145264757, 120),
#   (0.061950494245066816, 160),
#   (0.06140849795956313, 309),
#   (0.058436934256239144, 498),
#   (0.058159760613511614, 438),
#   (0.058105251321083386, 166),
#   (0.05795065631869611, 232),
#   (0.05715832602841611, 143),
#   (0.05657840643284783, 184),
#   (0.05630229202156964, 61),
#   (0.05575962790681806, 62),
#   (0.05336058015201946, 374),
#   (0.05249381975489018, 161),
#   (0.05216230526056147, 466),
#   (0.050578910274663345, 204),
#   (0.05025937165733816, 404),
#   (0.049373572833029865, 330),
#   (0.04891209900993286, 419),
#   (0.04827953107984106, 416),
#   (0.04802532168663839, 189),
#   (0.047640072641880374, 381),
#   (0.04744384385582318, 175),
#   (0.04691675836876564, 24),
#   (0.0465975133580612, 328),
#   (0.0465379015801537, 302),
#   (0.04649489587216834, 283),
#   (0.04637645243474595, 14),
#   (0.04628231295712948, 267),
#   (0.04620416264564914, 277),
#   (0.045576786698071976, 386),
#   (0.044477122451226404, 34),
#   (0.04447536451529461, 25),
#   (0.04439600399373795, 446),
#   (0.04402642286938664, 209),
#   (0.04363692466453984, 92),
#   (0.04325191728750724, 312),
#   (0.0431490447176953, 450),
#   (0.043071039319598416, 38),
#   (0.04272795133286286, 445),
#   (0.04260789488966294, 147),
#   (0.04203857469906472, 323),
#   (0.041966728390709834, 229),
#   (0.04187910353950933, 428),
#   (0.041839833406527124, 23),
#   (0.041638381185021445, 415),
#   (0.041586529443224524, 168),
#   (0.041500737697654645, 358),
#   (0.04142148150553555, 280),
#   (0.041343138918581594, 211),
#   (0.041186017135907756, 223),
#   (0.04087162242510394, 497),
#   (0.04042417334940688, 176),
#   (0.040360833712623556, 387),
#   (0.040332944612820956, 198),
#   (0.04029333102168496, 6),
#   (0.04014928310111793, 268),
#   (0.040026029621210955, 174),
#   (0.03932794401887109, 360),
#   (0.03890697031492403, 97),
#   (0.03799333635995629, 465),
#   (0.03796652965749527, 458),
#   (0.037744228841533924, 159),
#   (0.037576720848557475, 359),
#   (0.03747712313418827, 236),
#   (0.037442167023835286, 172),
#   (0.037340519338208145, 57),
#   (0.0371975173808867, 308),
#   (0.03716278717506496, 40),
#   (0.037153745715811495, 105),
#   (0.03686152184878994, 224),
#   (0.03673758768819458, 318),
#   (0.036706217566776896, 4),
#   (0.03655694976164373, 401),
#   (0.03652441835271861, 388),
#   (0.036471734262125, 11),
#   (0.036148327160035194, 5),
#   (0.036024382889836504, 22),
#   (0.035658838272347435, 341),
#   (0.03563599853828676, 451),
#   (0.03534378915537561, 378),
#   (0.03507363662666411, 260),
#   (0.034882898516385846, 263)],
#  10: [(0.29893678973860105, 425),
#   (0.203708066655593, 466),
#   (0.1759235129914741, 428),
#   (0.15283862966413658, 408),
#   (0.14088464062991105, 465),
#   (0.11487176603422816, 135),
#   (0.1041994051626153, 17),
#   (0.09519777933373472, 312),
#   (0.09239614986168612, 13),
#   (0.06592907550912314, 44),
#   (0.05792637462875662, 306),
#   (0.056900560338419504, 29),
#   (0.051955910828481514, 43),
#   (0.051789432020478136, 402),
#   (0.051381270264917484, 454),
#   (0.05135902104304275, 67),
#   (0.05024061501678753, 141),
#   (0.050001030934331, 275),
#   (0.04991960990137301, 327),
#   (0.04991960990137301, 274),
#   (0.048747788903452584, 212),
#   (0.04750552549680482, 469),
#   (0.04742553743664805, 59),
#   (0.04727700074511964, 382),
#   (0.04720625799225048, 217),
#   (0.047185824061214014, 403),
#   (0.04647914399653636, 395),
#   (0.04540186707390754, 445),
#   (0.04532872083507432, 414),
#   (0.0447439181340355, 188),
#   (0.044661619820149566, 305),
#   (0.04456105469909789, 464),
#   (0.04453235999747657, 354),
#   (0.04368077155025146, 85),
#   (0.04332292703285232, 197),
#   (0.043152829380234396, 100),
#   (0.04302597953531898, 187),
#   (0.04292983367186478, 405),
#   (0.04185261233587159, 374),
#   (0.04181480916140138, 436),
#   (0.04177976294839955, 293),
#   (0.041164984103279616, 479),
#   (0.04093448557219088, 45),
#   (0.040090979291059876, 308),
#   (0.03995816345045541, 5),
#   (0.038701949275349215, 83),
#   (0.03862412885383116, 7),
#   (0.03857609866763659, 353),
#   (0.03811489258816144, 424),
#   (0.03784542427160262, 207),
#   (0.037841836655690915, 210),
#   (0.03767879387717213, 224),
#   (0.037617934887345196, 364),
#   (0.03751485052270828, 184),
#   (0.037478833281747094, 438),
#   (0.037338894491908046, 456),
#   (0.03715440946052149, 352),
#   (0.0366753746157994, 498),
#   (0.03640500905476016, 427),
#   (0.03624442038691575, 393),
#   (0.036243733783969785, 74),
#   (0.036223777398066044, 92),
#   (0.03607316139564638, 96),
#   (0.036016130305320054, 431),
#   (0.03590938914159308, 486),
#   (0.03588563028810159, 216),
#   (0.03552126169694031, 223),
#   (0.03548982342545128, 35),
#   (0.03548477979017511, 281),
#   (0.03508322953688081, 93),
#   (0.0349559447692902, 389),
#   (0.034684718469796275, 120),
#   (0.03422343810317771, 15),
#   (0.03388160608058812, 143),
#   (0.03372205548331608, 430),
#   (0.03355170883650506, 52),
#   (0.033266599092304124, 107),
#   (0.033266599092304124, 351),
#   (0.03298896280548279, 473),
#   (0.03289756672680814, 146),
#   (0.032601215421264235, 179),
#   (0.03198134684574952, 280),
#   (0.03190815925329316, 349),
#   (0.03180355007313482, 444),
#   (0.03110544906147981, 12),
#   (0.031092419797406283, 256),
#   (0.030655830341591358, 6),
#   (0.030651466004156153, 99),
#   (0.030353397452504278, 302),
#   (0.03026483609829929, 394),
#   (0.030243644446618975, 46),
#   (0.030038305491680684, 94),
#   (0.0298793640281654, 415),
#   (0.029877719895695716, 204),
#   (0.0297548646031684, 409),
#   (0.029600034980054663, 399),
#   (0.029577396205192476, 104),
#   (0.029285748669742234, 416)],
#  11: [(0.20165256224413863, 419),
#   (0.09609186974928641, 465),
#   (0.06825834466984564, 348),
#   (0.06624091774129419, 3),
#   (0.06513325947946236, 245),
#   (0.0589555530192839, 413),
#   (0.058783431416981474, 388),
#   (0.05661715311301381, 412),
#   (0.05539173608990249, 117),
#   (0.05140609729902531, 196),
#   (0.049267330571996955, 477),
#   (0.047784586774209624, 411),
#   (0.047323008930354384, 2),
#   (0.04597824880697811, 404),
#   (0.044352657614404434, 475),
#   (0.04202994613877041, 155),
#   (0.04198672039457282, 328),
#   (0.041633344536904426, 235),
#   (0.04074845900215748, 358),
#   (0.040724251308280966, 363),
#   (0.040510230382771156, 62),
#   (0.03993071518792371, 466),
#   (0.03990581673290716, 164),
#   (0.03961029261086275, 257),
#   (0.03950970921321111, 47),
#   (0.038473625271518305, 451),
#   (0.03804270031105169, 267),
#   (0.03784784911581626, 321),
#   (0.03779283351685391, 227),
#   (0.037653491672767075, 386),
#   (0.03744073354743468, 401),
#   (0.03735543634720074, 418),
#   (0.03724290044919938, 488),
#   (0.03697324617744025, 272),
#   (0.036710115195427, 460),
#   (0.036471734262125, 9),
#   (0.03629663926261935, 61),
#   (0.03536798189408246, 309),
#   (0.035185376267999176, 248),
#   (0.03500787928133642, 160),
#   (0.034741638549092825, 147),
#   (0.03434394296772732, 387),
#   (0.03424128607419826, 329),
#   (0.03416392978494547, 268),
#   (0.0339639746305844, 270),
#   (0.0338556038529576, 298),
#   (0.0336257394480371, 461),
#   (0.03359870828777801, 417),
#   (0.033544780208641135, 161),
#   (0.033295445023559224, 232),
#   (0.03323348643869345, 264),
#   (0.0332321079490244, 450),
#   (0.03312103668777527, 287),
#   (0.03310220353099641, 454),
#   (0.03305147989726791, 359),
#   (0.03274188722851939, 60),
#   (0.03255793625096339, 29),
#   (0.0324885369100476, 82),
#   (0.032468149291836695, 323),
#   (0.03242171959755033, 143),
#   (0.03213157324261258, 259),
#   (0.03210697680444359, 362),
#   (0.03202515144156828, 22),
#   (0.03200537867616688, 188),
#   (0.03199070991470859, 346),
#   (0.031946510592856886, 305),
#   (0.03185743237785177, 380),
#   (0.031850263307378696, 6),
#   (0.0317574055960488, 296),
#   (0.03174023291560989, 414),
#   (0.031640028824600396, 290),
#   (0.031634208557009394, 340),
#   (0.03147279550610248, 495),
#   (0.0314064790065336, 144),
#   (0.0313267322691108, 459),
#   (0.03113803842484609, 478),
#   (0.030971957255887698, 21),
#   (0.030842455711055143, 208),
#   (0.030842007399327617, 469),
#   (0.030684737354498212, 249),
#   (0.030581684674183818, 474),
#   (0.030547089791433734, 106),
#   (0.030515876786544164, 487),
#   (0.03030253260415316, 374),
#   (0.030045651423902225, 360),
#   (0.029871455119274463, 497),
#   (0.029828937445003364, 297),
#   (0.029396000692557052, 66),
#   (0.02927186798105397, 213),
#   (0.02912177936814316, 343),
#   (0.029082451673406277, 494),
#   (0.02907965600118151, 311),
#   (0.02903919183658518, 172),
#   (0.028943721778232047, 337),
#   (0.028752310911067377, 373),
#   (0.02872623973923316, 381),
#   (0.028712987823575613, 174),
#   (0.02869895260954016, 23)],
#  12: [(0.2218748461266379, 402),
#   (0.13913297641538797, 466),
#   (0.1336616040087933, 408),
#   (0.12638062400942743, 428),
#   (0.12294333868972428, 312),
#   (0.10376019888086145, 395),
#   (0.10085166185790445, 100),
#   (0.0981347129940625, 92),
#   (0.09369125324737661, 325),
#   (0.09090118253178686, 146),
#   (0.08757006053950009, 306),
#   (0.08590223077240619, 329),
#   (0.08211339212207423, 188),
#   (0.08196235944543522, 305),
#   (0.08125870005443026, 29),
#   (0.08035022123649986, 59),
#   (0.07847788636890399, 15),
#   (0.07813177032659585, 43),
#   (0.07662517327392533, 485),
#   (0.07595147335301407, 445),
#   (0.07518993885861752, 480),
#   (0.07458366759894293, 52),
#   (0.07306298952851883, 187),
#   (0.073062639910749, 46),
#   (0.07184234987325262, 308),
#   (0.07160434615625333, 5),
#   (0.07139199792570337, 209),
#   (0.07090449095085936, 224),
#   (0.07081030032323855, 409),
#   (0.06940591225934459, 217),
#   (0.0689884797268941, 454),
#   (0.06865080242000914, 427),
#   (0.06758246135425794, 97),
#   (0.06616244575103468, 450),
#   (0.06598194215249341, 16),
#   (0.06583906083430012, 302),
#   (0.06474912823811751, 465),
#   (0.06391277389074908, 328),
#   (0.06329110702545175, 484),
#   (0.06318893333520405, 399),
#   (0.06306893850631998, 400),
#   (0.06272279645066248, 284),
#   (0.06195680577681297, 256),
#   (0.061925172183243594, 326),
#   (0.06159671476331078, 353),
#   (0.061230646312153005, 330),
#   (0.0610002610672055, 444),
#   (0.059792863358525156, 223),
#   (0.059521180999803976, 135),
#   (0.05932866402629256, 44),
#   (0.05911923841250997, 368),
#   (0.05677483225075508, 147),
#   (0.05597610096293587, 214),
#   (0.055325457452549014, 45),
#   (0.055111376943640523, 267),
#   (0.05418701498153124, 393),
#   (0.05403493225667803, 436),
#   (0.05353708295056284, 168),
#   (0.05344018442618543, 386),
#   (0.053184292229359775, 403),
#   (0.052530709055221524, 342),
#   (0.0522801082928853, 53),
#   (0.051683067126835465, 115),
#   (0.051513400104153395, 207),
#   (0.05044397342328818, 275),
#   (0.050110203407813046, 280),
#   (0.049635586782623746, 259),
#   (0.049338803841348734, 17),
#   (0.049238712881020164, 141),
#   (0.04904286803695761, 320),
#   (0.04896608305775751, 438),
#   (0.0487352763934935, 500),
#   (0.04833621788037921, 184),
#   (0.048320706250338, 143),
#   (0.04830919020102199, 13),
#   (0.04828143235271185, 389),
#   (0.04814639278472403, 7),
#   (0.04791695098558541, 6),
#   (0.047380366705310845, 216),
#   (0.04728899241317487, 358),
#   (0.04724027403042325, 424),
#   (0.047154015549483154, 120),
#   (0.0471353859689348, 232),
#   (0.04695922426406173, 34),
#   (0.046858943485819135, 354),
#   (0.04576309589934645, 1),
#   (0.04570747903180657, 204),
#   (0.04569986258971199, 498),
#   (0.04560763751000008, 473),
#   (0.0453038646229001, 104),
#   (0.04517101390093061, 106),
#   (0.04483894403050232, 3),
#   (0.044813035457457545, 379),
#   (0.04462061711598118, 35),
#   (0.04434269593518118, 472),
#   (0.044017047919193954, 55),
#   (0.04383873347647128, 416),
#   (0.0437120382640719, 227)],
#  13: [(0.17039314012511514, 135),
#   (0.14157196344707274, 479),
#   (0.12597308832644427, 449),
#   (0.1186526935989004, 214),
#   (0.11631834260576022, 115),
#   (0.10823107397117133, 17),
#   (0.10578000008564757, 343),
#   (0.10492370082448411, 149),
#   (0.09780962151954159, 344),
#   (0.09654178118359213, 445),
#   (0.0964287941933509, 213),
#   (0.09239614986168612, 10),
#   (0.08935091909098047, 472),
#   (0.08709043416490872, 425),
#   (0.07831956610421512, 52),
#   (0.07715674304803864, 74),
#   (0.07694644198892592, 55),
#   (0.0733831041112102, 444),
#   (0.06629772844780266, 306),
#   (0.0658686762755986, 402),
#   (0.0658625849494974, 210),
#   (0.06547289061800425, 364),
#   (0.06425863141025943, 188),
#   (0.0641404393243129, 305),
#   (0.061219760509659944, 187),
#   (0.06018513452190548, 96),
#   (0.059203467689683306, 281),
#   (0.058584016094694595, 466),
#   (0.055923797517395964, 353),
#   (0.05573079581647397, 216),
#   (0.054976429473530326, 53),
#   (0.05463573348284553, 59),
#   (0.05440445413822251, 217),
#   (0.053865765975775984, 120),
#   (0.05301291950505269, 7),
#   (0.05281258445020584, 428),
#   (0.05119878408205718, 308),
#   (0.05109003400329983, 395),
#   (0.05105576005375297, 224),
#   (0.051029169628481016, 5),
#   (0.0498494588782843, 209),
#   (0.049013528243873915, 387),
#   (0.04881738888941823, 256),
#   (0.0487566246837079, 268),
#   (0.04830919020102199, 12),
#   (0.04694762138305986, 465),
#   (0.046784729878810216, 312),
#   (0.04602641530374307, 4),
#   (0.04598634342074745, 29),
#   (0.04583777690729634, 408),
#   (0.045803574759958436, 143),
#   (0.04483698832968041, 97),
#   (0.04439424250836888, 15),
#   (0.044300843299636176, 232),
#   (0.044086773745153685, 159),
#   (0.042456513860336206, 223),
#   (0.042325794114530954, 184),
#   (0.04228515798499142, 438),
#   (0.04195991877402784, 331),
#   (0.041885026520854005, 31),
#   (0.04180299267042257, 464),
#   (0.04130665544794717, 393),
#   (0.0406070002963267, 399),
#   (0.040455980353240356, 403),
#   (0.03950450667952371, 35),
#   (0.03908522271194271, 100),
#   (0.03907358081190332, 352),
#   (0.038617001892197085, 405),
#   (0.03851924678097613, 207),
#   (0.03834926100604232, 212),
#   (0.038262322677146514, 6),
#   (0.03822869952304531, 379),
#   (0.038171267957919905, 450),
#   (0.03815928004334472, 329),
#   (0.03788534159204289, 469),
#   (0.03761194085803571, 328),
#   (0.0375824699710235, 293),
#   (0.03753801871627802, 389),
#   (0.03741157630491494, 67),
#   (0.03734838843978187, 384),
#   (0.03727184951780933, 382),
#   (0.03711609558528313, 415),
#   (0.037018441195774014, 424),
#   (0.03655396116410217, 93),
#   (0.03632536877836848, 16),
#   (0.036302573972691245, 431),
#   (0.0360519741771318, 280),
#   (0.03528306911592196, 92),
#   (0.03501414545921503, 456),
#   (0.03441448786065031, 349),
#   (0.034413750434202625, 498),
#   (0.0343023467433453, 436),
#   (0.03401858547288571, 354),
#   (0.03394864942827916, 484),
#   (0.03379045282890854, 486),
#   (0.03377917666644199, 134),
#   (0.03360273157377712, 49),
#   (0.03341117904339271, 473)],
#  14: [(0.3843245773602439, 166),
#   (0.10194917241435232, 230),
#   (0.10166267602559899, 459),
#   (0.09425772484605215, 374),
#   (0.09237288190683786, 161),
#   (0.08938305653656277, 461),
#   (0.08075926520030355, 321),
#   (0.07970472590034369, 232),
#   (0.07675419269485277, 309),
#   (0.07213040499797271, 279),
#   (0.07204333083438293, 414),
#   (0.07012113729296927, 143),
#   (0.06743183330683658, 160),
#   (0.06698564682368996, 469),
#   (0.06637378958579675, 417),
#   (0.06609473537204247, 38),
#   (0.06500433385336604, 475),
#   (0.06331422374227094, 460),
#   (0.05944169186526298, 62),
#   (0.05771594009233337, 378),
#   (0.0569633117764471, 263),
#   (0.05528838824144455, 180),
#   (0.055126463112253464, 297),
#   (0.05372514048497117, 66),
#   (0.051803673392938544, 498),
#   (0.05166090990269463, 24),
#   (0.0506208273265945, 277),
#   (0.04987892176416527, 404),
#   (0.04919041398067543, 23),
#   (0.049059395239733815, 175),
#   (0.04903522058164536, 121),
#   (0.04748304471568094, 320),
#   (0.04637645243474595, 9),
#   (0.0450001397052852, 198),
#   (0.042207836562928897, 401),
#   (0.042052060789410525, 269),
#   (0.04202581753771024, 35),
#   (0.041355112780493926, 474),
#   (0.040864118186673425, 196),
#   (0.04019550512665055, 282),
#   (0.03917779613707289, 47),
#   (0.038962670887975025, 441),
#   (0.03894472596814916, 88),
#   (0.03882589149451263, 21),
#   (0.03848444407035476, 117),
#   (0.03816467108666098, 179),
#   (0.03810065962217468, 245),
#   (0.03805053310425798, 260),
#   (0.03740831774411318, 265),
#   (0.03740614479380932, 90),
#   (0.03724890248884663, 200),
#   (0.037148760941203104, 89),
#   (0.037038607626534305, 443),
#   (0.03701688137617425, 362),
#   (0.0366746718922656, 497),
#   (0.036621633344640865, 478),
#   (0.03648693663771713, 381),
#   (0.036461913975355593, 211),
#   (0.03624560684169761, 302),
#   (0.03592556171614395, 473),
#   (0.03578879989206088, 407),
#   (0.03506431339770232, 487),
#   (0.035064143560844196, 22),
#   (0.034754176065275574, 202),
#   (0.03470391004557808, 201),
#   (0.034183993381144084, 348),
#   (0.03401359911287203, 87),
#   (0.033843890065976, 120),
#   (0.033631796558597375, 266),
#   (0.0335157971656132, 174),
#   (0.03330395769288815, 216),
#   (0.03296189969864638, 446),
#   (0.03273440368848583, 406),
#   (0.032643435939723645, 360),
#   (0.03228907674000078, 132),
#   (0.032167980542787696, 496),
#   (0.03214705291223879, 264),
#   (0.032066978312896476, 39),
#   (0.03183846564883137, 20),
#   (0.03182667032240992, 363),
#   (0.03137543131589375, 359),
#   (0.031220329566746734, 369),
#   (0.031220329566746734, 370),
#   (0.030924467350335227, 82),
#   (0.03082641804930543, 204),
#   (0.030162697139311048, 380),
#   (0.030143238565862426, 57),
#   (0.03003628859370987, 106),
#   (0.029691748647932635, 173),
#   (0.029480848288256842, 413),
#   (0.029311196357066558, 442),
#   (0.02912207095173315, 34),
#   (0.02890040293446049, 105),
#   (0.028727860123175446, 477),
#   (0.02833661134018632, 412),
#   (0.028300092902465643, 270),
#   (0.028180138126890297, 462),
#   (0.028172037866535733, 32)],
#  15: [(0.507734909948116, 16),
#   (0.3643606217674816, 480),
#   (0.3614900847352149, 485),
#   (0.35929288403027143, 484),
#   (0.15785672906681206, 329),
#   (0.15313251457208196, 59),
#   (0.13580385734460565, 328),
#   (0.1260755009379708, 168),
#   (0.1247700873767109, 115),
#   (0.12360614785030449, 330),
#   (0.1186110519081076, 306),
#   (0.10734630738243259, 34),
#   (0.10672224706693546, 217),
#   (0.10587002083904175, 353),
#   (0.10570842662585264, 52),
#   (0.10300738850870891, 224),
#   (0.10277478864546327, 343),
#   (0.10123903302020595, 223),
#   (0.09869418774583301, 256),
#   (0.09674109252956908, 499),
#   (0.09577346630875606, 214),
#   (0.09512158307047662, 409),
#   (0.09413411173573506, 187),
#   (0.09277329909227146, 188),
#   (0.09260265945212956, 305),
#   (0.08963520092556183, 500),
#   (0.08957998433786887, 157),
#   (0.0894824464044024, 402),
#   (0.08767164405803655, 462),
#   (0.08764644321837471, 32),
#   (0.08755236352998529, 463),
#   (0.08689604227932683, 46),
#   (0.08689490620038004, 444),
#   (0.08274510443169893, 466),
#   (0.08142584141820293, 427),
#   (0.08117128070916059, 312),
#   (0.07966395842949157, 207),
#   (0.07854165579503962, 171),
#   (0.07852837743082815, 209),
#   (0.07847788636890399, 12),
#   (0.07837610608333753, 43),
#   (0.0752146961351711, 29),
#   (0.07474984727020906, 395),
#   (0.07404207213308248, 445),
#   (0.07344987683401723, 18),
#   (0.07339533889967223, 400),
#   (0.07333429312142081, 399),
#   (0.07215341149109426, 454),
#   (0.0713681699454384, 284),
#   (0.07103312792201126, 97),
#   (0.07049856778197902, 213),
#   (0.07024413730269513, 419),
#   (0.06996007954340895, 44),
#   (0.06944126315026557, 92),
#   (0.06936582802602817, 358),
#   (0.06855063478862361, 21),
#   (0.06702901766064799, 146),
#   (0.06690927147377683, 100),
#   (0.06568051339370963, 408),
#   (0.06537669171060272, 384),
#   (0.06514094567682473, 331),
#   (0.06504798535859799, 362),
#   (0.06475708553330833, 228),
#   (0.0641697083576729, 388),
#   (0.06337487436660365, 483),
#   (0.06321092488380728, 428),
#   (0.0630824658722826, 208),
#   (0.06264982116015491, 120),
#   (0.06261973003088538, 450),
#   (0.06213110506541849, 481),
#   (0.06211503189428515, 37),
#   (0.06205501533874702, 482),
#   (0.061883640141765124, 60),
#   (0.061798542559988394, 172),
#   (0.06124638920656329, 143),
#   (0.06123567393975338, 341),
#   (0.06110635599103647, 4),
#   (0.06096747709888085, 418),
#   (0.060949275685247946, 259),
#   (0.06045699234995828, 216),
#   (0.06025882197151961, 453),
#   (0.060006332029656266, 6),
#   (0.059919682305726286, 232),
#   (0.059341219996663364, 326),
#   (0.05895666591824289, 487),
#   (0.058854046176403566, 325),
#   (0.05881398505180919, 379),
#   (0.05875544106312087, 302),
#   (0.058669965330605, 478),
#   (0.058385536261553926, 20),
#   (0.05834486242553039, 340),
#   (0.05819383074360391, 112),
#   (0.05732357409673073, 159),
#   (0.05618445158330745, 477),
#   (0.05604852791923338, 308),
#   (0.055862846938576946, 5),
#   (0.05566686204106004, 348),
#   (0.055504875190873194, 438)],
#  16: [(0.507734909948116, 15),
#   (0.36557761709988695, 480),
#   (0.3642768776584981, 484),
#   (0.34030868973262424, 485),
#   (0.14580946142214082, 329),
#   (0.14254532222553604, 59),
#   (0.13183230250357755, 328),
#   (0.1261760616324309, 115),
#   (0.12236481514350227, 34),
#   (0.1152889129620004, 330),
#   (0.11042321380143902, 499),
#   (0.10939911109288881, 168),
#   (0.10834042804541859, 462),
#   (0.10830928605207074, 32),
#   (0.10819302686907029, 463),
#   (0.10672921568795231, 343),
#   (0.10514072291023352, 52),
#   (0.10222973666039196, 306),
#   (0.10139283698540161, 500),
#   (0.09681045758403407, 353),
#   (0.09607256365738191, 224),
#   (0.09121274852123486, 223),
#   (0.09092882617122798, 217),
#   (0.0903288545017068, 214),
#   (0.09004636197730935, 409),
#   (0.0891671067318836, 481),
#   (0.08914403941054011, 37),
#   (0.08905790698769461, 482),
#   (0.08892714207898375, 483),
#   (0.08875096625694373, 256),
#   (0.08687189015291887, 187),
#   (0.08670595670844261, 157),
#   (0.08669671508956601, 207),
#   (0.08645008342074363, 171),
#   (0.08516309996967084, 444),
#   (0.08041277947238921, 427),
#   (0.07864602660535827, 188),
#   (0.07850137151806656, 305),
#   (0.07817779557933316, 43),
#   (0.07766330162181737, 18),
#   (0.07734807085272077, 46),
#   (0.07427321982362348, 21),
#   (0.0741745382496254, 358),
#   (0.07350179524993783, 388),
#   (0.072822430899958, 312),
#   (0.0721316522271766, 44),
#   (0.0700810208457723, 228),
#   (0.06958062556079368, 362),
#   (0.06883506525605887, 466),
#   (0.06842945411210753, 402),
#   (0.06803401531844384, 399),
#   (0.06624733202949969, 213),
#   (0.06608935263835486, 326),
#   (0.0659882587818851, 172),
#   (0.06598194215249341, 12),
#   (0.06597067778790487, 400),
#   (0.06575369412448513, 29),
#   (0.06478126267106021, 341),
#   (0.06462130445559774, 209),
#   (0.06381369406618226, 478),
#   (0.06303798520916346, 20),
#   (0.06301691615800316, 454),
#   (0.06272923793861095, 487),
#   (0.06233337100961524, 340),
#   (0.06211251825321775, 450),
#   (0.06134858652992572, 303),
#   (0.06081626033575783, 4),
#   (0.060659677091677675, 453),
#   (0.0601036083097331, 259),
#   (0.05971937073322047, 408),
#   (0.0595063901091508, 159),
#   (0.05943469206711473, 445),
#   (0.05937940745617632, 245),
#   (0.05904496682646065, 117),
#   (0.05894190363300469, 451),
#   (0.05863236068169519, 146),
#   (0.058574464977425085, 92),
#   (0.057862574436613114, 208),
#   (0.05739398259560029, 384),
#   (0.0573388228461077, 348),
#   (0.05698454720793066, 395),
#   (0.05575488202806341, 97),
#   (0.05561713764727047, 216),
#   (0.05556675712720671, 331),
#   (0.05516752412745178, 418),
#   (0.05492302514875867, 325),
#   (0.05486879392520832, 287),
#   (0.05470785841064398, 419),
#   (0.05459373844540142, 308),
#   (0.054463565010776496, 284),
#   (0.05441287698001482, 5),
#   (0.05432601825543408, 120),
#   (0.05426024774922829, 100),
#   (0.05406607029339225, 60),
#   (0.05391397774277645, 488),
#   (0.053722740259704804, 477),
#   (0.053335658649776796, 112),
#   (0.05197992530293422, 428)],
#  17: [(0.11779151241969374, 425),
#   (0.11674743897118214, 135),
#   (0.10823107397117133, 13),
#   (0.1041994051626153, 10),
#   (0.08363440117956397, 466),
#   (0.06810762553731003, 306),
#   (0.06634889164127938, 188),
#   (0.06622685490113696, 305),
#   (0.0585656064480931, 402),
#   (0.05531788165352068, 395),
#   (0.05480883109102165, 445),
#   (0.05385933653413446, 424),
#   (0.0532788366806813, 100),
#   (0.05268060657657646, 428),
#   (0.051102429836471085, 465),
#   (0.05072958697936459, 399),
#   (0.050197036364837265, 217),
#   (0.04987871899953699, 224),
#   (0.04977611604359255, 187),
#   (0.049338803841348734, 12),
#   (0.04888677394574753, 256),
#   (0.04673820427084576, 415),
#   (0.046695379032409334, 52),
#   (0.04661042268398517, 302),
#   (0.04615361499661117, 15),
#   (0.04561197620457959, 408),
#   (0.045249842663372876, 67),
#   (0.04479036394002615, 327),
#   (0.04479036394002615, 274),
#   (0.04477270338327385, 223),
#   (0.04473209228540307, 312),
#   (0.04471994523856038, 143),
#   (0.04426239010590835, 444),
#   (0.044173945265697574, 308),
#   (0.04410075267658413, 212),
# ...
#   (0.04772506860206479, 201),
#   (0.04758040305926825, 200),
#   (0.047246061113479204, 165),
#   (0.046517934508791436, 45),
#   (0.046372498367247654, 273),
#   (0.046124506609629065, 90),
#   (0.04526037742611964, 331),
#   (0.04451560176171523, 89),
#   (0.04451195306391175, 318),
#   (0.04312858617918089, 407),
#   (0.04301634011195379, 269),
#   (0.042249967446877465, 164),
#   (0.041412871434694125, 348),
#   (0.04140964763332742, 417),
#   (0.03976539000647405, 381),
#   (0.03953931769411223, 245),
#   (0.039517671432128934, 100),
#   (0.03911598296360894, 412),
#   (0.038677368514176615, 168),
#   (0.038122104859946306, 180),
#   (0.0379373221885481, 211),
#   (0.037826546623901613, 196),
#   (0.037666185851525404, 330),
#   (0.037590014454254285, 208),
#   (0.03741798437448334, 87),
#   (0.036358744712454004, 202),
#   (0.03606486294527006, 419),
#   (0.03602233128257572, 444),
#   (0.036017283900900726, 117),
#   (0.03586415527429282, 270),
#   (0.03573910740856264, 477),
#   (0.035325661464021864, 329),
#   (0.03518042252551287, 358),
#   (0.035171632906801496, 264),
#   (0.03505229572219193, 106),
#   (0.03498287603633771, 97),
#   (0.03446842110046973, 460),
#   (0.03437621586303869, 144),
#   (0.03424062481934299, 79),
#   (0.03360088206737777, 80),
#   (0.03345740456360859, 148),
#   (0.03319798295728963, 272),
#   (0.033172739724852254, 203),
#   (0.03301666489724273, 383),
#   (0.03292725189500914, 207),
#   (0.03290090331794876, 76)],
#  496: [(0.6038233448772871, 173),
#   (0.3849268401352308, 22),
#   (0.3514897041689605, 23),
#   (0.350704911161111, 359),
#   (0.3423888252247366, 497),
#   (0.3372478875207375, 360),
#   (0.3015122212823325, 175),
#   (0.3003038796835993, 174),
#   (0.29275849817512173, 442),
#   (0.24961335574894233, 440),
#   (0.2447734925628768, 171),
#   (0.2277461002182153, 18),
#   (0.19914674456851655, 495),
#   (0.18799210723456541, 19),
#   (0.18422731860476652, 25),
#   (0.18197067881436377, 176),
#   (0.17738741094795152, 441),
#   (0.17121189296411796, 61),
#   (0.1645360828886092, 443),
#   (0.16248011777557522, 494),
#   (0.15704996887731765, 24),
#   (0.13684893728920522, 446),
#   (0.13504873685312843, 277),
#   (0.1328117438147655, 413),
#   (0.12421324223723851, 172),
#   (0.1230499510744772, 487),
#   (0.12147764628515076, 1),
#   (0.12111184087486782, 21),
#   (0.11710945360061499, 341),
#   (0.11680160540236102, 20),
#   (0.11503058281438855, 340),
#   (0.11249598496217551, 488),
#   (0.09848575636561982, 60),
#   (0.07691460490593431, 406),
#   (0.06952639717307645, 57),
#   (0.06195095841185502, 266),
#   (0.0601682874831923, 211),
#   (0.059951090195872345, 2),
#   (0.058595379585838395, 381),
#   (0.05639323241131858, 105),
#   (0.05420531815910422, 331),
#   (0.05409371265568731, 87),
#   (0.05363184454477947, 88),
#   (0.0525616277235311, 3),
#   (0.05177695464792475, 260),
#   (0.05144649804023764, 365),
#   (0.051143130693653664, 201),
#   (0.050903065299638624, 265),
#   (0.050290776646693916, 214),
#   (0.04979634676879461, 200),
#   (0.047123915361304704, 90),
#   (0.04640545653905069, 62),
#   (0.04624116544044639, 89),
#   (0.045939352752997424, 353),
#   (0.045050847874342756, 460),
#   (0.04485580978623589, 106),
#   (0.0447981540362611, 485),
#   (0.044655050361744025, 407),
#   (0.043884152078868005, 213),
#   (0.0437021925846516, 264),
#   (0.042159235368668085, 15),
#   (0.040628802163541936, 166),
#   (0.040300481390013944, 161),
#   (0.04019071565112091, 16),
#   (0.040164878022165014, 209),
#   (0.040158884140607955, 180),
#   (0.04005308488584921, 428),
#   (0.039519089139010005, 66),
#   (0.03926912651873178, 450),
#   (0.03886684610557384, 270),
#   (0.038377213673066776, 165),
#   (0.03818304747229504, 46),
#   (0.038155972644115896, 324),
#   (0.037892102551113194, 164),
#   (0.03788133131049159, 217),
#   (0.0376057968752222, 159),
#   (0.03755386816372376, 202),
#   (0.03745674488663088, 480),
#   (0.037316656660674075, 127),
#   (0.03731313188813251, 4),
#   (0.03727702122877401, 474),
#   (0.03720029135304291, 269),
#   (0.03718882881387249, 230),
#   (0.0369535975610367, 419),
#   (0.03694275996939717, 160),
#   (0.03680527358055975, 384),
#   (0.03655878176626733, 115),
#   (0.03645906880522274, 300),
#   (0.036406545824711, 484),
#   (0.03635304415946871, 343),
#   (0.03601005880370158, 43),
#   (0.035565919638609785, 321),
#   (0.03537100882140606, 427),
#   (0.03530103313531057, 400),
#   (0.03495325968280304, 309),
#   (0.034637076052100965, 97),
#   (0.03430615914514963, 459),
#   (0.03418969120212438, 59)],
#  497: [(0.7035737662036846, 22),
#   (0.6183601817340841, 360),
#   (0.5774312956892617, 359),
#   (0.5373618644219552, 23),
#   (0.4923390721080343, 175),
#   (0.48621872447232634, 174),
#   (0.3423888252247366, 496),
#   (0.31973278930548804, 173),
#   (0.3113322602790977, 441),
#   (0.26256243266307255, 443),
#   (0.21708859209232223, 24),
#   (0.1996250884862296, 440),
#   (0.18379642673041346, 413),
#   (0.18259090561577315, 442),
#   (0.1777776605732383, 487),
#   (0.1745652559309722, 172),
#   (0.15999048716930944, 20),
#   (0.15859925311315187, 61),
#   (0.15489502742191527, 495),
#   (0.15177558520982404, 341),
#   (0.1500476568779555, 340),
#   (0.14922464660601942, 25),
#   (0.14702821354189974, 277),
#   (0.14207910497619744, 19),
#   (0.14146423964701269, 176),
#   (0.14046367377727237, 60),
#   (0.1389463491341685, 21),
#   (0.1332755903673115, 446),
#   (0.12780323124937154, 488),
#   (0.12627567241623183, 494),
#   (0.11615425607339142, 171),
#   (0.11470506587211125, 18),
#   (0.09748273457862415, 1),
#   (0.09184597020072369, 348),
#   (0.08370498079537038, 269),
#   (0.07824958750369626, 90),
#   (0.0778677706960835, 260),
#   (0.07759275684559665, 87),
#   (0.07391504133164438, 105),
#   (0.07365187934096196, 201),
#   (0.07347017380938378, 265),
#   (0.07285309268884205, 407),
#   (0.07218009898222329, 200),
#   (0.07159615432838144, 245),
#   (0.07031832400056603, 202),
#   (0.06584981829953682, 57),
#   (0.06433896086142307, 117),
#   (0.06345558011057824, 88),
#   (0.060815755534492484, 62),
#   (0.06026620262065927, 89),
#   (0.055811262204778896, 477),
#   (0.055218551859934656, 196),
#   (0.05369375972410735, 266),
#   (0.052067049664017484, 3),
#   (0.04910445615544174, 406),
#   (0.04856413029161189, 385),
#   (0.04675027138702868, 195),
#   (0.04453266569105281, 419),
#   (0.043386843325037706, 263),
#   (0.042827598712661695, 378),
#   (0.04272148978154181, 6),
#   (0.04236397933424565, 308),
#   (0.042223633360509785, 5),
#   (0.042061063991060584, 414),
#   (0.04183870141973223, 264),
#   (0.041203739472296066, 180),
#   (0.041012211785669744, 2),
#   (0.04087162242510394, 9),
#   (0.04056809889499216, 412),
#   (0.04053371068851691, 148),
#   (0.04049321847235137, 209),
#   (0.040143331407505714, 203),
#   (0.03970443239627441, 96),
#   (0.03968407814531106, 270),
#   (0.03958851492461041, 474),
#   (0.039488344131667, 388),
#   (0.03935556591382931, 318),
#   (0.03912325097571063, 211),
#   (0.039056821907650446, 281),
#   (0.03901354384197946, 321),
#   (0.038984948523809, 381),
#   (0.03800396507958944, 106),
#   (0.037941562614700115, 338),
#   (0.03760324562353377, 66),
#   (0.037593453839230184, 230),
#   (0.03753803819462729, 331),
#   (0.03727997308825807, 272),
#   (0.03721968114998399, 164),
#   (0.037103306560316976, 97),
#   (0.03674574035021256, 267),
#   (0.0366746718922656, 14),
#   (0.03632018357597662, 438),
#   (0.0361202474260051, 320),
#   (0.03607194430904515, 498),
#   (0.03596900510294685, 386),
#   (0.03581356047622825, 417),
#   (0.03565817397202304, 184),
#   (0.035337909859631866, 404)],
#  498: [(0.2226124165979552, 302),
#   (0.2032727078208336, 267),
#   (0.20068086653601142, 386),
#   (0.1687130928156288, 212),
#   (0.16316441580731006, 382),
#   (0.15539602237958625, 352),
#   (0.15217620613062788, 415),
#   (0.15041650044705818, 274),
#   (0.15041650044705818, 327),
#   (0.1435194725354182, 67),
#   (0.14124736856966627, 107),
#   (0.14124736856966627, 351),
#   (0.1394968393178183, 33),
#   (0.13941389088280437, 85),
#   (0.13827177514786823, 197),
#   (0.13673227172878905, 141),
#   (0.1360802320224002, 275),
#   (0.12044677408136632, 438),
#   (0.11987329755930502, 51),
#   (0.11819287641207848, 469),
#   (0.11815451908175219, 424),
#   (0.11755308089490962, 184),
#   (0.10889659068417146, 414),
#   (0.1078113748692044, 86),
#   (0.10686476907652327, 387),
#   (0.10630463923858385, 268),
#   (0.10435463495044833, 308),
#   (0.10300878629460598, 129),
#   (0.10258909358880064, 204),
#   (0.10005022072852843, 153),
#   (0.10004319244012932, 154),
#   (0.10003060127693313, 367),
#   (0.10000512006509649, 5),
#   (0.10000469134326496, 355),
#   (0.09628389913224082, 216),
#   (0.09573151869715188, 416),
#   (0.09042582270739015, 120),
#   (0.08985941399084918, 232),
#   (0.08775241210042996, 143),
#   (0.08620766216451377, 468),
#   (0.08538957920200724, 455),
#   (0.08490460567787976, 230),
#   (0.08015446848140179, 179),
#   (0.07835993457708171, 35),
#   (0.07737439418624606, 384),
#   (0.07379687798298941, 473),
#   (0.07105491173581921, 210),
#   (0.07079976991196132, 280),
#   (0.07063449555644472, 364),
#   (0.07001287618569176, 405),
#   (0.06977786152944229, 293),
#   (0.06954662984419986, 209),
#   (0.06931355137299283, 6),
#   (0.06776723054214004, 96),
#   (0.06751817594104983, 180),
#   (0.0672605107303936, 331),
#   (0.06666189376648556, 281),
#   (0.06554983682326317, 321),
#   (0.06553663163031578, 458),
#   (0.06513657001119921, 306),
#   (0.0649921403926013, 379),
#   (0.06485540996811763, 217),
#   (0.06450476354882233, 97),
#   (0.06339238546966186, 417),
#   (0.06215138535635563, 282),
#   (0.061359218553998715, 4),
#   (0.05998635554011178, 150),
#   (0.059717512772410705, 450),
#   (0.059552511448278965, 381),
#   (0.05944727243712897, 353),
#   (0.058436934256239144, 9),
#   (0.058227182351149785, 207),
#   (0.05716930182674111, 211),
#   (0.05536847684730916, 461),
#   (0.0551372576090568, 159),
#   (0.05512227254969519, 460),
#   (0.053962698021124494, 208),
#   (0.05357120968389379, 160),
#   (0.05347699892000019, 62),
#   (0.05346137262729556, 188),
#   (0.05336304013857442, 305),
#   (0.052973545830269746, 187),
#   (0.05219097037648561, 402),
#   (0.052036864004773795, 161),
#   (0.051803673392938544, 14),
#   (0.05165455806316702, 100),
#   (0.051337149073937306, 362),
#   (0.051193101171724896, 475),
#   (0.051008076855161455, 284),
#   (0.050983569762121726, 459),
#   (0.0500873902002891, 309),
#   (0.04933527319063434, 403),
#   (0.04916385350220034, 15),
#   (0.0481982689488189, 320),
#   (0.04790631441788685, 84),
#   (0.04788701313895452, 66),
#   (0.047771833899573006, 478),
#   (0.04769106739861538, 312)],
#  499: [(0.4236797836644115, 462),
#   (0.42355799872002264, 32),
#   (0.4231033515823727, 463),
#   (0.32102598955943895, 500),
#   (0.305979709617769, 34),
#   (0.21155918394200024, 303),
#   (0.19727252347954324, 481),
#   (0.19722148954048074, 37),
#   (0.19703093092496776, 482),
#   (0.18267686273571407, 483),
#   (0.17478048105441069, 453),
#   (0.16843360912936672, 118),
#   (0.16839290305778493, 350),
#   (0.16824088989832853, 119),
#   (0.15428350162948837, 186),
#   (0.14688354540137008, 369),
#   (0.14688354540137008, 370),
#   (0.14500405531275107, 28),
#   (0.1449791652933417, 27),
#   (0.1448861695180166, 452),
#   (0.14204648370869413, 294),
#   (0.11042321380143902, 16),
#   (0.10402677381344692, 480),
#   (0.09674109252956908, 15),
#   (0.09510667030740573, 29),
#   (0.0937618020313947, 454),
#   (0.0922825105791065, 484),
#   (0.08926141820770667, 306),
#   (0.08754510604103707, 187),
#   (0.08373836378653707, 214),
#   (0.08281355953913748, 108),
#   (0.08265902915727279, 390),
#   (0.08249087102664378, 109),
#   (0.08203045205946728, 392),
#   (0.08187152644679427, 391),
#   (0.08178941406843919, 110),
#   (0.07684823630039732, 229),
#   (0.07444485958428453, 145),
#   (0.07299325050329335, 121),
#   (0.07269247015568156, 326),
#   (0.0712090934658566, 329),
#   (0.07079921475797668, 30),
#   (0.06965527120912485, 224),
#   (0.06946036609337497, 333),
#   (0.06862575531147211, 116),
#   (0.06664984788109472, 223),
#   (0.06606934909601186, 485),
#   (0.0655330995297715, 41),
#   (0.0648304913236175, 449),
#   (0.06359737573453585, 213),
#   (0.06351282882293056, 325),
#   (0.0628739989454012, 64),
#   (0.06287381840649399, 188),
#   (0.06275817343264695, 305),
#   (0.06218753052166993, 346),
#   (0.062032921487518156, 189),
#   (0.06185111814810532, 330),
#   (0.06167343205262386, 58),
#   (0.06158910899394873, 365),
#   (0.06156185567787663, 324),
#   (0.06034103586078664, 90),
#   (0.0597034975166074, 63),
#   (0.05938659406227464, 328),
#   (0.05874820778482295, 401),
#   (0.05870679501265314, 366),
#   (0.058607411184641744, 140),
#   (0.0585642582903942, 65),
#   (0.057857613969066364, 193),
#   (0.05770358087340604, 312),
#   (0.057262566233615, 432),
#   (0.057027035200008014, 433),
#   (0.05577746965944259, 259),
#   (0.05558522722775439, 178),
#   (0.0545172854594147, 249),
#   (0.05426058237264103, 168),
#   (0.053854574432653686, 185),
#   (0.05312546751337612, 146),
#   (0.052929999892703576, 144),
#   (0.052707932371949213, 315),
#   (0.05270339906141744, 38),
#   (0.05250721912494346, 181),
#   (0.05231006973607197, 296),
#   (0.05228180914046943, 78),
#   (0.05220372930131649, 182),
#   (0.052001128627530285, 357),
#   (0.0517107622352012, 126),
#   (0.051512995251250304, 288),
#   (0.05148216447909886, 489),
#   (0.05133322842823226, 98),
#   (0.051281102966979186, 248),
#   (0.05109606919372668, 26),
#   (0.05109367934181203, 73),
#   (0.05081930986974958, 231),
#   (0.050803472963500844, 170),
#   (0.05079894779125416, 400),
#   (0.050676636662984574, 40),
#   (0.05053521545368961, 372),
#   (0.050399583436946324, 138)],
#  500: [(0.32102598955943895, 499),
#   (0.29752739352993196, 463),
#   (0.2957700011538971, 462),
#   (0.29568498333022175, 32),
#   (0.24552937636417527, 34),
#   (0.1817030352643019, 303),
#   (0.17322939942561433, 483),
#   (0.17155365289834465, 482),
#   (0.16971230802405837, 481),
#   (0.1696684038480831, 37),
#   (0.1465647224590037, 453),
#   (0.14639420182424534, 452),
#   (0.14484218019020784, 28),
#   (0.1448173179567452, 27),
#   (0.14214498797787745, 186),
#   (0.14116914625193636, 119),
#   (0.13934783591171998, 118),
#   (0.13931415912350228, 350),
#   (0.13739244410754367, 369),
#   (0.13739244410754367, 370),
#   (0.13347934960070362, 294),
#   (0.11469409874708979, 480),
#   (0.1116784132796958, 306),
#   (0.10398898257141391, 484),
#   (0.10139283698540161, 16),
#   (0.09774715115113466, 390),
#   (0.09770572973568271, 29),
#   (0.09767808842039444, 214),
#   (0.09599252467094693, 108),
#   (0.09576641402257524, 187),
#   (0.0956184834490871, 109),
#   (0.09348161838518369, 229),
#   (0.092514664628022, 392),
#   (0.09233542692558216, 391),
#   (0.09224281986375803, 110),
#   (0.09002800030847878, 454),
#   (0.08963520092556183, 15),
#   (0.08287318598604639, 326),
#   (0.07839341803689454, 223),
#   (0.07781486745545003, 325),
#   (0.07746439407962066, 329),
#   (0.07714090651936245, 224),
#   (0.07117136802960564, 189),
#   (0.06866285500461827, 330),
#   (0.06609901673736555, 213),
#   (0.0660700567936225, 188),
#   (0.0659485329195582, 305),
#   (0.06532725268813756, 168),
#   (0.06524700045817149, 401),
#   (0.06518020158874745, 485),
#   (0.06484267575814939, 30),
#   (0.06454279829855514, 328),
#   (0.06392702070828593, 400),
#   (0.0626881098761768, 365),
#   (0.06254898471622186, 312),
#   (0.060841162434473885, 333),
#   (0.060292380208387494, 41),
#   (0.060127921699154915, 145),
#   (0.058782169957881825, 121),
#   (0.05866416759040035, 366),
#   (0.05807203734598347, 256),
#   (0.05796289333625847, 337),
#   (0.057900963494718224, 193),
#   (0.057838633183259505, 249),
#   (0.05698438071722014, 427),
#   (0.05695567099800999, 346),
#   (0.056625468083013476, 324),
#   (0.05644332180552576, 296),
#   (0.0559895230330221, 140),
#   (0.05583036728466725, 78),
#   (0.05569548356321844, 38),
#   (0.05534620629958729, 449),
#   (0.0550158516451557, 112),
#   (0.05459606279636665, 259),
#   (0.054557423981567474, 322),
#   (0.053647844898794275, 357),
#   (0.053501565940814295, 58),
#   (0.053418798505648214, 40),
#   (0.05305867669511968, 279),
#   (0.05295498730405697, 231),
#   (0.05235238440020381, 92),
#   (0.05226984653150959, 146),
#   (0.0522595188165342, 248),
#   (0.05216441970395172, 298),
#   (0.0517926520865011, 63),
#   (0.05173909099999868, 310),
#   (0.0516329366055708, 323),
#   (0.05155189724346481, 147),
#   (0.051422154124553955, 64),
#   (0.051277205392546425, 250),
#   (0.050977876831359306, 185),
#   (0.05084779726872371, 52),
#   (0.05080436457670927, 65),
#   (0.05068663172028444, 235),
#   (0.050448439059710234, 124),
#   (0.050051098980887526, 297),
#   (0.0500054463108843, 47),
#   (0.04977263915225152, 102)]}

# %% [markdown]
# # Get Predictions

# %%
# retrieve item description
def get_item(id):
    description = df.loc[df['id'] == id]['description'].tolist()[0]
    return description

item(1)
# Out:
# active classic boxers there s a reason why our boxers are a cult favorite they keep their cool especially in sticky situations the quick drying lightweight underwear takes up minimal space in a travel pack an exposed brushed waistband offers next to skin softness five panel construction with a traditional boxer back for a classic fit and a functional fly made of oz recycled polyester with moisture wicking performance inseam size m is recyclable through the common threads recycling program details silky capilene fabric is ultralight breathable and quick to dry exposed brushed elastic waistband for comfort panel construction with traditional boxer back inseam size m is fabric oz all recycled polyester with gladiodor natural odor control for the garment recyclable through the common threads recycling program weight g oz made in mexico

# %%
# get n number of similar product ids from cosine similarity results
def get_recommendations(item_id, num_of_rec=3):
    # get n number of records (n = num_of_rec)
    recs = results[item_id][:num_of_rec]
    for idx, rec in enumerate(recs):
        print('Recommendation {}: {}\nScore: {}'.format(idx, get_item(rec[1]), rec[0]))
        print('---------------------------------------------------------------------')

# %%
get_recommendations(1, 3)
# Out:
# Recommendation 0: cap boxer briefs on bivy or belay the form fitting capilene boxer briefs stay dry and comfortable made from recycled polyester the underwear excels at moisture wicking and has gladiodor natural odor control for the garment exposed elastic waistband is brushed for softness the hem is coverstitched for a smooth glide beneath shorts or pants fully functioning fly and supportive front panel keep you covered inseam size m recyclable through the common threads recycling program details moisture wicking capilene fabric with gladiodor for exceptional next to skin comfort and natural odor control for the garment brushed elastic waistband supportive front panel cover stitched hem for smooth glide under shorts or pants won t restrict mobility inseam size m is fabric oz all recycled polyester with gladiodor natural odor control for the garment recyclable through the common threads recycling program weight g oz made in usa
# Score: 0.1998035147475983
# ---------------------------------------------------------------------
# Recommendation 1: cap bottoms spring skiing is as transient as the wind move fast move light and still stay dry with our lightest weight capilene performance baselayer these bottoms wick perspiration breathe and dry quickly under a shell they insulate without overheating the waistband is brushed for softness inseams are set forward to prevent chafe and a gusseted crotch improves mobility with a functional fly made from oz all recycled polyester with gladiodor natural odor control for the garment and upf sun protection recyclable through the common threads recycling program details silky soft capilene is the lightest of our technical baselayer fabrics fast drying highly breathable and sleek it provides upf sun protection and can be worn either on its own or under layers in cooler temps elastic waistband is brushed for next to skin softness streamlined functional fly inseams are set forward to prevent chafe fabric oz recycled polyester with gladiodor natural odor control for the garment and upf sun protection recyclable through the common threads recycling program weight g oz made in usa
# Score: 0.15182409328775237
# ---------------------------------------------------------------------
# Recommendation 2: active boxer briefs a no fuss travel companion these skivvies love sink and creek baths and they dry in a flash the quick wicking underwear breathes exceptionally well keeping you comfortable in any condition an exposed elastic waistband is brushed for no chafe softness the hem is coverstitched for a smooth glide beneath shorts or pants with a inseam size m an easy access fly and a supportive front panel made from polyester recycled with moisture wicking performance recyclable through the common threads recycling program details moisture wicking capilene fabric with an open knit weave for breathability brushed elastic waistband for next to skin softness supportive front panel cover stitched hem for smooth glide under shorts or pants won t restrict mobility inseam size m is fabric oz polyester recycled with gladiodor natural odor control for the garment recyclable through the common threads recycling program weight g oz made in usa
# Score: 0.14951420049273145
# ---------------------------------------------------------------------
